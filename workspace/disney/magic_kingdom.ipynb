# %%
import re
import os
import time

import requests
import datetime
import pandas as pd

from bs4 import BeautifulSoup

# %%
def get_times():
    obj = {}
    
    response = requests.get('https://www.laughingplace.com/w/p/magic-kingdom-current-wait-times/')
    bs = BeautifulSoup(response.text)

    for row in bs.select('table.lp_attraction tr'):
        columns = row.select('td')

        ride_name = columns[0].text
        obj[ride_name] = re.sub(
            r'(open|closed)',
            '-',
            re.sub(r'\s+minutes', '', columns[1].text, flags=re.IGNORECASE),
            flags=re.IGNORECASE
        )

    last_check = bs.select('#f_lastcheck')[0].text

    return pd.DataFrame(
        [
            [datetime.datetime.now()] + [last_check] + list(obj.values())
        ],
        columns=['time'] + ['last_check'] + list(obj.keys())
    )

# %%
def load_data(ride_times_path):
    df = pd.DataFrame()
    if os.path.exists(ride_times_path):
        df = pd.read_csv(ride_times_path)

    return df

def merge(df, df_current):
    if df.empty:
        df = df_current
    else:
        if len(df[df['last_check'] == df_current['last_check'][0]]) == 0:
            df = pd.concat([df, df_current])

    return df

# %%
ride_times_path = '../../data/disney/magic_kingdom_ride_times.csv'



while True:

    df = load_data(ride_times_path)
    original_n = len(df)

    df = merge(df, get_times())
    df.to_csv(ride_times_path, index=0)

    if original_n != len(df):
        display(
            df.tail(n=1)
        )

    time.sleep(60 * 4)
# Out:
#                          time        last_check Astro Orbiter The Barnstormer  \
# 0  2022-07-29 08:42:59.214587  9:40am on Friday             5               5
#
#   Big Thunder Mountain Railroad Buzz Lightyear’s Space Ranger Spin  \
# 0                             5                                 30
#
#   Country Bear Jamboree Dumbo the Flying Elephant Enchanted Tales with Belle  \
# 0                     -                         5                          -
#
#   Frontierland Shootin’ Arcade  ... Seven Dwarfs Mine Train Space Mountain  \
# 0                            -  ...                      60             35
#
#   Splash Mountain Swiss Family Treehouse Tom Sawyer Island  \
# 0              35                      -                 -
#
#   Tomorrowland Speedway Tomorrowland Transit Authority PeopleMover  \
# 0                    20                                          -
#
#   Under the Sea ~ Journey of The Little Mermaid  \
# 0                                             5
#
#   Walt Disney’s Carousel of Progress Walt Disney’s Enchanted Tiki Room
# 0                                  5                                 -
#
# [1 rows x 33 columns]
#                          time        last_check Astro Orbiter The Barnstormer  \
# 0  2022-07-29 08:50:59.611010  9:48am on Friday             5               5
#
#   Big Thunder Mountain Railroad Buzz Lightyear’s Space Ranger Spin  \
# 0                            25                                 30
#
#   Country Bear Jamboree Dumbo the Flying Elephant Enchanted Tales with Belle  \
# 0                     -                         5                          -
#
#   Frontierland Shootin’ Arcade  ... Seven Dwarfs Mine Train Space Mountain  \
# 0                            -  ...                      50             35
#
#   Splash Mountain Swiss Family Treehouse Tom Sawyer Island  \
# 0              45                      -                 -
#
#   Tomorrowland Speedway Tomorrowland Transit Authority PeopleMover  \
# 0                    25                                          -
#
#   Under the Sea ~ Journey of The Little Mermaid  \
# 0                                             5
#
#   Walt Disney’s Carousel of Progress Walt Disney’s Enchanted Tiki Room
# 0                                  5                                 -
#
# [1 rows x 33 columns]
#                          time        last_check Astro Orbiter The Barnstormer  \
# 0  2022-07-29 08:59:00.535107  9:56am on Friday             5               5
#
#   Big Thunder Mountain Railroad Buzz Lightyear’s Space Ranger Spin  \
# 0                            25                                 30
#
#   Country Bear Jamboree Dumbo the Flying Elephant Enchanted Tales with Belle  \
# 0                     -                         5                          -
#
#   Frontierland Shootin’ Arcade  ... Seven Dwarfs Mine Train Space Mountain  \
# 0                            -  ...                      55             30
#
#   Splash Mountain Swiss Family Treehouse Tom Sawyer Island  \
# 0              45                      -                 -
#
#   Tomorrowland Speedway Tomorrowland Transit Authority PeopleMover  \
# 0                    25                                          -
#
#   Under the Sea ~ Journey of The Little Mermaid  \
# 0                                             5
#
#   Walt Disney’s Carousel of Progress Walt Disney’s Enchanted Tiki Room
# 0                                  5                                 -
#
# [1 rows x 33 columns]
#                          time         last_check Astro Orbiter  \
# 0  2022-07-29 09:07:00.951466  10:04am on Friday             5
#
#   The Barnstormer Big Thunder Mountain Railroad  \
# 0               5                            40
#
#   Buzz Lightyear’s Space Ranger Spin Country Bear Jamboree  \
# 0                                 30                     -
#
#   Dumbo the Flying Elephant Enchanted Tales with Belle  \
# 0                         5                          -
#
#   Frontierland Shootin’ Arcade  ... Seven Dwarfs Mine Train Space Mountain  \
# 0                            -  ...                      60             30
#
#   Splash Mountain Swiss Family Treehouse Tom Sawyer Island  \
# 0              45                      -                 -
#
#   Tomorrowland Speedway Tomorrowland Transit Authority PeopleMover  \
# 0                    25                                          -
#
#   Under the Sea ~ Journey of The Little Mermaid  \
# 0                                             5
#
#   Walt Disney’s Carousel of Progress Walt Disney’s Enchanted Tiki Room
# 0                                  5                                 -
#
# [1 rows x 33 columns]
#                          time         last_check Astro Orbiter  \
# 0  2022-07-29 09:15:01.567143  10:12am on Friday             5
#
#   The Barnstormer Big Thunder Mountain Railroad  \
# 0               5                            40
#
#   Buzz Lightyear’s Space Ranger Spin Country Bear Jamboree  \
# 0                                 40                     -
#
#   Dumbo the Flying Elephant Enchanted Tales with Belle  \
# 0                         5                          -
#
#   Frontierland Shootin’ Arcade  ... Seven Dwarfs Mine Train Space Mountain  \
# 0                            -  ...                      55             25
#
#   Splash Mountain Swiss Family Treehouse Tom Sawyer Island  \
# 0              45                      -                 -
#
#   Tomorrowland Speedway Tomorrowland Transit Authority PeopleMover  \
# 0                    25                                          -
#
#   Under the Sea ~ Journey of The Little Mermaid  \
# 0                                             5
#
#   Walt Disney’s Carousel of Progress Walt Disney’s Enchanted Tiki Room
# 0                                  5                                 -
#
# [1 rows x 33 columns]
#                          time         last_check Astro Orbiter  \
# 0  2022-07-29 09:23:02.748549  10:21am on Friday             5
#
#   The Barnstormer Big Thunder Mountain Railroad  \
# 0               5                            40
#
#   Buzz Lightyear’s Space Ranger Spin Country Bear Jamboree  \
# 0                                 40                     -
#
#   Dumbo the Flying Elephant Enchanted Tales with Belle  \
# 0                         5                          -
#
#   Frontierland Shootin’ Arcade  ... Seven Dwarfs Mine Train Space Mountain  \
# 0                            -  ...                      65             25
#
#   Splash Mountain Swiss Family Treehouse Tom Sawyer Island  \
# 0              45                      -                 -
#
#   Tomorrowland Speedway Tomorrowland Transit Authority PeopleMover  \
# 0                    25                                          -
#
#   Under the Sea ~ Journey of The Little Mermaid  \
# 0                                             5
#
#   Walt Disney’s Carousel of Progress Walt Disney’s Enchanted Tiki Room
# 0                                  5                                 -
#
# [1 rows x 33 columns]
#                          time         last_check Astro Orbiter  \
# 0  2022-07-29 09:31:10.402006  10:28am on Friday             5
#
#   The Barnstormer Big Thunder Mountain Railroad  \
# 0               5                            40
#
#   Buzz Lightyear’s Space Ranger Spin Country Bear Jamboree  \
# 0                                 40                     -
#
#   Dumbo the Flying Elephant Enchanted Tales with Belle  \
# 0                         5                          -
#
#   Frontierland Shootin’ Arcade  ... Seven Dwarfs Mine Train Space Mountain  \
# 0                            -  ...                      65             25
#
#   Splash Mountain Swiss Family Treehouse Tom Sawyer Island  \
# 0              40                      -                 -
#
#   Tomorrowland Speedway Tomorrowland Transit Authority PeopleMover  \
# 0                    25                                          -
#
#   Under the Sea ~ Journey of The Little Mermaid  \
# 0                                             5
#
#   Walt Disney’s Carousel of Progress Walt Disney’s Enchanted Tiki Room
# 0                                  5                                 -
#
# [1 rows x 33 columns]
#                          time         last_check Astro Orbiter  \
# 0  2022-07-29 09:39:11.178666  10:36am on Friday             5
#
#   The Barnstormer Big Thunder Mountain Railroad  \
# 0               5                            40
#
#   Buzz Lightyear’s Space Ranger Spin Country Bear Jamboree  \
# 0                                 25                     -
#
#   Dumbo the Flying Elephant Enchanted Tales with Belle  \
# 0                         5                          -
#
#   Frontierland Shootin’ Arcade  ... Seven Dwarfs Mine Train Space Mountain  \
# 0                            -  ...                      65             25
#
#   Splash Mountain Swiss Family Treehouse Tom Sawyer Island  \
# 0              40                      -                 -
#
#   Tomorrowland Speedway Tomorrowland Transit Authority PeopleMover  \
# 0                    25                                          -
#
#   Under the Sea ~ Journey of The Little Mermaid  \
# 0                                             5
#
#   Walt Disney’s Carousel of Progress Walt Disney’s Enchanted Tiki Room
# 0                                  5                                 -
#
# [1 rows x 33 columns]
#                          time         last_check Astro Orbiter  \
# 0  2022-07-29 09:47:12.095433  10:44am on Friday             5
#
#   The Barnstormer Big Thunder Mountain Railroad  \
# 0               5                            40
#
#   Buzz Lightyear’s Space Ranger Spin Country Bear Jamboree  \
# 0                                 25                     -
#
#   Dumbo the Flying Elephant Enchanted Tales with Belle  \
# 0                         5                          -
#
#   Frontierland Shootin’ Arcade  ... Seven Dwarfs Mine Train Space Mountain  \
# 0                            -  ...                      75             30
#
#   Splash Mountain Swiss Family Treehouse Tom Sawyer Island  \
# 0              40                      -                 -
#
#   Tomorrowland Speedway Tomorrowland Transit Authority PeopleMover  \
# 0                    30                                          -
#
#   Under the Sea ~ Journey of The Little Mermaid  \
# 0                                             5
#
#   Walt Disney’s Carousel of Progress Walt Disney’s Enchanted Tiki Room
# 0                                  5                                 -
#
# [1 rows x 33 columns]
#                          time         last_check Astro Orbiter  \
# 0  2022-07-29 09:55:12.547863  10:52am on Friday             5
#
#   The Barnstormer Big Thunder Mountain Railroad  \
# 0               5                            40
#
#   Buzz Lightyear’s Space Ranger Spin Country Bear Jamboree  \
# 0                                 40                     -
#
#   Dumbo the Flying Elephant Enchanted Tales with Belle  \
# 0                         5                          -
#
#   Frontierland Shootin’ Arcade  ... Seven Dwarfs Mine Train Space Mountain  \
# 0                            -  ...                      75             35
#
#   Splash Mountain Swiss Family Treehouse Tom Sawyer Island  \
# 0              40                      -                 -
#
#   Tomorrowland Speedway Tomorrowland Transit Authority PeopleMover  \
# 0                    30                                          -
#
#   Under the Sea ~ Journey of The Little Mermaid  \
# 0                                             5
#
#   Walt Disney’s Carousel of Progress Walt Disney’s Enchanted Tiki Room
# 0                                  5                                 -
#
# [1 rows x 33 columns]
#                          time         last_check Astro Orbiter  \
# 0  2022-07-29 10:03:19.366217  11:00am on Friday            35
#
#   The Barnstormer Big Thunder Mountain Railroad  \
# 0               5                            40
#
#   Buzz Lightyear’s Space Ranger Spin Country Bear Jamboree  \
# 0                                 40                     -
#
#   Dumbo the Flying Elephant Enchanted Tales with Belle  \
# 0                         5                          -
#
#   Frontierland Shootin’ Arcade  ... Seven Dwarfs Mine Train Space Mountain  \
# 0                            -  ...                      75             35
#
#   Splash Mountain Swiss Family Treehouse Tom Sawyer Island  \
# 0              55                      -                 -
#
#   Tomorrowland Speedway Tomorrowland Transit Authority PeopleMover  \
# 0                    30                                          -
#
#   Under the Sea ~ Journey of The Little Mermaid  \
# 0                                             5
#
#   Walt Disney’s Carousel of Progress Walt Disney’s Enchanted Tiki Room
# 0                                  5                                 -
#
# [1 rows x 33 columns]
#                          time         last_check Astro Orbiter  \
# 0  2022-07-29 10:12:10.913976  11:07am on Friday            35
#
#   The Barnstormer Big Thunder Mountain Railroad  \
# 0               5                            40
#
#   Buzz Lightyear’s Space Ranger Spin Country Bear Jamboree  \
# 0                                 40                     -
#
#   Dumbo the Flying Elephant Enchanted Tales with Belle  \
# 0                         5                          -
#
#   Frontierland Shootin’ Arcade  ... Seven Dwarfs Mine Train Space Mountain  \
# 0                            -  ...                      75             40
#
#   Splash Mountain Swiss Family Treehouse Tom Sawyer Island  \
# 0              60                      -                 -
#
#   Tomorrowland Speedway Tomorrowland Transit Authority PeopleMover  \
# 0                    30                                          -
#
#   Under the Sea ~ Journey of The Little Mermaid  \
# 0                                             5
#
#   Walt Disney’s Carousel of Progress Walt Disney’s Enchanted Tiki Room
# 0                                  5                                 -
#
# [1 rows x 33 columns]
#                          time         last_check Astro Orbiter  \
# 0  2022-07-29 10:16:11.765208  11:15am on Friday            35
#
#   The Barnstormer Big Thunder Mountain Railroad  \
# 0               5                            40
#
#   Buzz Lightyear’s Space Ranger Spin Country Bear Jamboree  \
# 0                                 40                     -
#
#   Dumbo the Flying Elephant Enchanted Tales with Belle  \
# 0                         5                          -
#
#   Frontierland Shootin’ Arcade  ... Seven Dwarfs Mine Train Space Mountain  \
# 0                            -  ...                      75             45
#
#   Splash Mountain Swiss Family Treehouse Tom Sawyer Island  \
# 0              60                      -                 -
#
#   Tomorrowland Speedway Tomorrowland Transit Authority PeopleMover  \
# 0                    30                                          -
#
#   Under the Sea ~ Journey of The Little Mermaid  \
# 0                                             5
#
#   Walt Disney’s Carousel of Progress Walt Disney’s Enchanted Tiki Room
# 0                                  5                                 -
#
# [1 rows x 33 columns]
#                          time         last_check Astro Orbiter  \
# 0  2022-07-29 10:28:22.408256  11:24am on Friday            35
#
#   The Barnstormer Big Thunder Mountain Railroad  \
# 0               5                            40
#
#   Buzz Lightyear’s Space Ranger Spin Country Bear Jamboree  \
# 0                                 40                     -
#
#   Dumbo the Flying Elephant Enchanted Tales with Belle  \
# 0                         5                          -
#
#   Frontierland Shootin’ Arcade  ... Seven Dwarfs Mine Train Space Mountain  \
# 0                            -  ...                      75             65
#
#   Splash Mountain Swiss Family Treehouse Tom Sawyer Island  \
# 0              60                      -                 -
#
#   Tomorrowland Speedway Tomorrowland Transit Authority PeopleMover  \
# 0                    30                                          -
#
#   Under the Sea ~ Journey of The Little Mermaid  \
# 0                                            15
#
#   Walt Disney’s Carousel of Progress Walt Disney’s Enchanted Tiki Room
# 0                                  5                                 -
#
# [1 rows x 33 columns]
#                          time         last_check Astro Orbiter  \
# 0  2022-07-29 10:32:23.202589  11:32am on Friday            35
#
#   The Barnstormer Big Thunder Mountain Railroad  \
# 0               5                            40
#
#   Buzz Lightyear’s Space Ranger Spin Country Bear Jamboree  \
# 0                                 40                     -
#
#   Dumbo the Flying Elephant Enchanted Tales with Belle  \
# 0                         5                          -
#
#   Frontierland Shootin’ Arcade  ... Seven Dwarfs Mine Train Space Mountain  \
# 0                            -  ...                      75             65
#
#   Splash Mountain Swiss Family Treehouse Tom Sawyer Island  \
# 0              60                      -                 -
#
#   Tomorrowland Speedway Tomorrowland Transit Authority PeopleMover  \
# 0                    30                                          -
#
#   Under the Sea ~ Journey of The Little Mermaid  \
# 0                                            20
#
#   Walt Disney’s Carousel of Progress Walt Disney’s Enchanted Tiki Room
# 0                                  5                                 -
#
# [1 rows x 33 columns]
#                          time         last_check Astro Orbiter  \
# 0  2022-07-29 10:40:30.960450  11:40am on Friday            35
#
#   The Barnstormer Big Thunder Mountain Railroad  \
# 0              20                            40
#
#   Buzz Lightyear’s Space Ranger Spin Country Bear Jamboree  \
# 0                                 40                     -
#
#   Dumbo the Flying Elephant Enchanted Tales with Belle  \
# 0                         5                          -
#
#   Frontierland Shootin’ Arcade  ... Seven Dwarfs Mine Train Space Mountain  \
# 0                            -  ...                      75             50
#
#   Splash Mountain Swiss Family Treehouse Tom Sawyer Island  \
# 0              60                      -                 -
#
#   Tomorrowland Speedway Tomorrowland Transit Authority PeopleMover  \
# 0                    30                                          -
#
#   Under the Sea ~ Journey of The Little Mermaid  \
# 0                                            20
#
#   Walt Disney’s Carousel of Progress Walt Disney’s Enchanted Tiki Room
# 0                                  5                                 -
#
# [1 rows x 33 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/danpasse/Documents/source/monte/workspace/disney/magic_kingdom.ipynb Cell 5 in <module>
#      <a href='vscode-notebook-cell:/Users/danpasse/Documents/source/monte/workspace/disney/magic_kingdom.ipynb#ch0000010?line=10'>11</a> if original_n != len(df):
#      <a href='vscode-notebook-cell:/Users/danpasse/Documents/source/monte/workspace/disney/magic_kingdom.ipynb#ch0000010?line=11'>12</a>     display(
#      <a href='vscode-notebook-cell:/Users/danpasse/Documents/source/monte/workspace/disney/magic_kingdom.ipynb#ch0000010?line=12'>13</a>         df.tail(n=1)
#      <a href='vscode-notebook-cell:/Users/danpasse/Documents/source/monte/workspace/disney/magic_kingdom.ipynb#ch0000010?line=13'>14</a>     )
# ---> <a href='vscode-notebook-cell:/Users/danpasse/Documents/source/monte/workspace/disney/magic_kingdom.ipynb#ch0000010?line=15'>16</a> time.sleep(60 * 4)
#
# KeyboardInterrupt:
