# %%
import re
import json
import os
import requests
import time
import numpy as np
import pandas as pd
from datetime import date

from bs4 import BeautifulSoup

# %% [markdown]
# ### scrap job postings

# %%
def save(df, cache_path):
    if not os.path.exists(cache_path):
        df.to_csv(cache_path, index=False)
        return df

    df_gospel = pd.read_csv(cache_path)
    df_gospel['cat_id'] = df_gospel['cat_id'].astype(int)
    df_gospel['job_id'] = df_gospel['job_id'].astype(int)

    df_gospel_slim = df_gospel[['cat_id', 'job_id']]
    df_scrapped_new = df \
        .merge(df_gospel_slim, indicator='i', how='outer')

    closed_jobs = df_scrapped_new.query('i == "right_only"')[['cat_id', 'job_id']]
    df_scrapped_new = df_scrapped_new.query('i == "left_only"').drop(['i'], axis=1)

    if not df_scrapped_new.empty:
        df_new = pd.concat([df_gospel, df_scrapped_new], axis=0)
    else:
        df_new = df_gospel.copy()

    for _, row in closed_jobs.iterrows():
        cat_id = row['cat_id']
        job_id = row['job_id']
        q = np.logical_and(df_new['cat_id'] == cat_id, df_new['job_id'] == job_id)
        q = np.logical_and(q, df_new['close'] == '-')
        df_new.loc[q, 'close'] = date.today()

    df_new.to_csv(cache_path, index=False)
    return df_new

# %%
def parse(cache_path):
    p = 1
    total = 20

    jobs = []
    while p <= total:
        url = f'https://jobs.disneycareers.com/search-jobs?k=imagineering&p={p}'
        response = requests.get(url)

        if response.status_code != 200:
            print(f'** ran into an issue {response.status_code}')
            break

        bs = BeautifulSoup(
            response.content,
            features='html.parser'
        )

        total = int(
            re.sub('of\s+', '', bs.select('.pagination-total-pages')[0].text)
        )

        rows = bs.select('#search-results-list tr')
        if len(rows) == 0:
            print('no rows to parse, stopping')
            break

        for row in bs.select('#search-results-list tr'):
            cols = row.select('td')
            if len(cols) < 3:
                continue

            link = cols[0].select('a')[0].attrs['href']
            cat_id = re.search(r'(?<=\/)(\d+)(?=\/\d+$)', link)
            job_id = re.search(r'(?<=\/)(\d+)$', link)

            jobs.append({
                'cat_id': cat_id.group(0),
                'job_id': job_id.group(0),
                'title': re.sub('\s+', ' ', cols[0].text).strip(),
                'date': re.sub('\s+', ' ', cols[1].text).strip(),
                'brand': re.sub('\s+', ' ', cols[2].text).strip(),
                'location': re.sub('\s+', ' ', cols[3].text).strip(),
                'url': f'https://jobs.disneycareers.com{link}',
                'close': '-'
            })

        p += 1
        time.sleep(5)
    
    df = pd.DataFrame(jobs)
    df['cat_id'] = df['cat_id'].astype(int)
    df['job_id'] = df['job_id'].astype(int)
    df['date'] = pd.to_datetime(df.date)

    save(df, cache_path)

parse('../../data/disney/jobs.csv')

# %%
df = pd.read_csv('../../data/disney/jobs.csv').sort_values(['date'], ascending=False)
df.head(n=5)
# Out:
#      cat_id       job_id                                              title  \
# 196     391  28088851264               Senior Manager – Ad Sales Automation
# 194     391  28089159280  Alternance - Assistant(e) Graphiste en Signalé...
# 195     391  28087427296                                  Software Engineer
# 192     391  28036542592  Assistant Manager - Content Development, Star ...
# 191     391  28031261712           Manager - Content Development, Star Plus
#
#            date                                      brand  \
# 196  2022-04-29                                       Star
# 194  2022-04-29                           Disneyland Paris
# 195  2022-04-28  Disney Media & Entertainment Distribution
# 192  2022-04-28                                       Star
# 191  2022-04-28                                       Star
#
#                 location                                                url  \
# 196        Mumbai, India  https://jobs.disneycareers.com/job/mumbai/seni...
# 194       Chessy, France  https://jobs.disneycareers.com/job/chessy/alte...
# 195  Richmond, Australia  https://jobs.disneycareers.com/job/richmond/so...
# 192        Mumbai, India  https://jobs.disneycareers.com/job/mumbai/assi...
# 191        Mumbai, India  https://jobs.disneycareers.com/job/mumbai/mana...
#
#     close
# 196     -
# 194     -
# 195     -
# 192     -
# 191     -

# %% [markdown]
# ### query

# %%
df[df.title.str.lower().str.contains('software')].head(n=5)
# Out:
#      cat_id       job_id                                            title  \
# 195     391  28087427296                                Software Engineer
# 172     391  27550252720                             Sr Software Engineer
# 6       391  24704474480  Associate R&D Imagineer-Tools Software Engineer
# 23      391  24200527168                   Control Software Dev Principal
# 47      391  21407266064                                Software Dev Lead
#
#            date                                      brand  \
# 195  2022-04-28  Disney Media & Entertainment Distribution
# 172  2022-04-19  Disney Media & Entertainment Distribution
# 6    2022-03-03                   Walt Disney Imagineering
# 23   2022-02-23                   Walt Disney Imagineering
# 47   2022-02-22                   Walt Disney Imagineering
#
#                                               location  \
# 195                                Richmond, Australia
# 172                Bristol, Connecticut, United States
# 6    Orlando, Florida, United States / Lake Buena V...
# 23                 Glendale, California, United States
# 47                 Glendale, California, United States
#
#                                                    url       close
# 195  https://jobs.disneycareers.com/job/richmond/so...           -
# 172  https://jobs.disneycareers.com/job/bristol/sr-...  2022-04-27
# 6    https://jobs.disneycareers.com/job/orlando/ass...           -
# 23   https://jobs.disneycareers.com/job/glendale/co...  2022-04-27
# 47   https://jobs.disneycareers.com/job/glendale/so...           -

# %%
df[df.title.str.lower().str.contains('data')].head(n=5)
# Out:
#      cat_id       job_id                           title        date  \
# 157     391  26192258656           Data Analyst, Disney+  2022-03-28
# 79      391  26229767216  HR Data & Process Analyst (IA)  2022-03-28
# 54      391  25922527760  Sr Analyst, Data Visualization  2022-03-23
# 118     391  25561189520                    Data Analyst  2022-03-17
# 119     391  25561188240                 Sr Data Analyst  2022-03-17
#
#                                    brand  \
# 157                     Disney Streaming
# 79               The Walt Disney Studios
# 54   The Walt Disney Company (Corporate)
# 118                     Disney Streaming
# 119                     Disney Streaming
#
#                                               location  \
# 157                               Melbourne, Australia
# 79   Burbank, California, United States / United St...
# 54                           California, United States
# 118            Santa Monica, California, United States
# 119            Santa Monica, California, United States
#
#                                                    url       close
# 157  https://jobs.disneycareers.com/job/melbourne/d...           -
# 79   https://jobs.disneycareers.com/job/burbank/hr-...  2022-04-29
# 54   https://jobs.disneycareers.com/job/california/...           -
# 118  https://jobs.disneycareers.com/job/santa-monic...           -
# 119  https://jobs.disneycareers.com/job/santa-monic...           -

# %%
df[df.title.str.lower().str.contains('ml')].head(n=5)
# Out:
#    cat_id       job_id                                              title  \
# 7     391  24429981920  Senior AI/ML Research Scientist, Disney Resear...
#
#          date                     brand                             location  \
# 7  2022-02-27  Walt Disney Imagineering  Glendale, California, United States
#
#                                                  url close
# 7  https://jobs.disneycareers.com/job/glendale/se...     -

# %% [markdown]
# ### scrap job descriptions

# %%
gosbel_json = []
if os.path.exists('../../data/disney/job_descriptions.json'):
    with open('../../data/disney/job_descriptions.json', 'r') as reader:
        gosbel_json = json.loads(reader.read())

not_closed = df[df['close'] == '-']
for _, row in not_closed.loc[:1].iterrows():
    url = row['url']
    cat_id = row['cat_id']
    job_id = row['job_id']

    if any(filter(lambda a: a['cat_id'] == cat_id and a['job_id'] == job_id, gosbel_json)):
        print(f'already pulled {cat_id}/{job_id}')
        continue

    response = requests.get(url)
    if response.status_code == 200:
        bs = BeautifulSoup(
            response.content,
            features='html.parser'
        )

        description = bs.select('.ats-description')[0]

        gosbel_json.append({
            'cat_id': cat_id,
            'job_id': job_id,
            'description': re.sub('\s+', ' ', f'<html><body>{description}</body></html>')
        })

        time.sleep(5)

with open('../../data/disney/job_descriptions.json', 'w') as writer:
    writer.write(
        json.dumps(gosbel_json, indent=3)
    )
# Out:
# already pulled 391/28088851264
# already pulled 391/28089159280
# already pulled 391/28087427296
# already pulled 391/28036542592
# already pulled 391/28031261712
# already pulled 391/28047612016
# already pulled 391/27996730304
# already pulled 391/27991931456
# already pulled 391/27991924976
# already pulled 391/28013695616
# already pulled 391/28018869648
# already pulled 391/27930208640
# already pulled 391/27934916224
# already pulled 391/27930209104
# already pulled 391/27873373664
# already pulled 391/27855101056
# already pulled 391/27851186288
# already pulled 391/27851185408
# already pulled 391/27873373936
# already pulled 391/27861261296
# already pulled 391/27868816304
# already pulled 391/27880153024
# already pulled 391/25947875248
# already pulled 391/27873375440
# already pulled 391/7255959040
# already pulled 391/26439104800
# already pulled 391/27780781936
# already pulled 391/27716762704
# already pulled 391/26469543424
# already pulled 391/26288058352
# already pulled 391/27699308208
# already pulled 391/26606093104
# already pulled 391/26644660320
# already pulled 391/27662461456
# already pulled 391/23892498304
# already pulled 391/27559459632
# already pulled 391/27629594304
# already pulled 391/27625241008
# already pulled 391/27550311504
# already pulled 391/27064544304
# already pulled 391/27611761792
# already pulled 391/27635838304
# already pulled 391/27629588832
# already pulled 391/27579281248
# already pulled 391/27579278544
# already pulled 391/27550252288
# already pulled 391/27478059936
# already pulled 391/27478059952
# already pulled 391/27457761616
# already pulled 391/26779119872
# already pulled 391/27517914032
# already pulled 391/27478059968
# already pulled 391/27506595200
# already pulled 391/27506594224
# already pulled 391/27506594064
# already pulled 391/27478060016
# already pulled 391/27446648784
# already pulled 391/26156952000
# already pulled 391/4534138000
# already pulled 391/26415117168
# already pulled 391/26156951968
# already pulled 391/27225844592
# already pulled 391/27225844352
# already pulled 391/27441961376
# already pulled 391/26200510976
# already pulled 391/27272804544
# already pulled 391/26156951712
# already pulled 391/12128248944
# already pulled 391/27266426816
# already pulled 391/27200312192
# already pulled 391/27211199744
# already pulled 391/27168034960
# already pulled 391/27155014208
# already pulled 391/26410631728
# already pulled 391/27155015808
# already pulled 391/26699601072
# already pulled 391/27155014240
# already pulled 391/23385116672
# already pulled 391/27103436176
# already pulled 391/26994281984
# already pulled 391/27088782608
# already pulled 391/27082386416
# already pulled 391/27077496880
# already pulled 391/26992390832
# already pulled 391/26469540640
# already pulled 391/27032698496
# already pulled 391/20143592448
# already pulled 391/26812101776
# already pulled 391/26800277248

# %%
from IPython.display import display, HTML

gosbel_json = []
with open('../../data/disney/job_descriptions.json', 'r') as reader:
    gosbel_json = json.loads(reader.read())

display(HTML(gosbel_json[0]['description']))
# Out:
# <html><body><div class="ats-description"> <h4>Job Summary:</h4> <div class="additional-field-value-razor"><br/>“Any sufficiently complex technology is indistinguishable from magic.” - Arthur C Clarke<br/><br/><strong>The Team</strong><br/><br/>In a time where children carry devices with AI in their pockets, robots deliver fast food meals, and other science fictions have become mundane reality, we need new magic: New ways to connect with our guests, to surprise them, make them smile, and open their minds to magic - not just in our parks and resorts, but everywhere in the world.<br/><br/>At Disney Research Imagineering this emerges from the application of bleeding edge science to everything from enabling new guest-facing experiences in the parks to assisting cast members and transforming critical business processes.<br/><br/>At Disney Research, we focus on new ideas and ways of thinking, working to solve the biggest challenges that are otherwise unsolvable without deep understanding of both the complexities of the Disney business, and the opportunities afforded by bleeding edge scientific exploration and application.<br/><br/>Our work is centered on 4 key areas<ul><li>Character Intelligence</li><li>General AI/Data Analytics</li><li>Computational Robotics</li><li>Interactive Immersion</li></ul>and is organized around core platforms that enable rapid integration, evaluation, communication and transfer of research concepts and results to the business.<br/><br/><strong>The Role</strong><br/><br/>We are looking for deep applied scientists who are passionate about their field of expertise and want to use their domain knowledge to create magic for our guests and fellow cast members.<br/><br/>As a member of Disney Research Imagineering you will be part of a team that defines and maintains a vision of the future enabled by a melding of deep science with deep artistry within a company that provides an unparalleled platform to share this vision with the world. You will work with partners across the company and academic/industry research teams across the globe to realize this vision: working with talent and leveraging unique data sets and content from the entire spectrum of Disney properties including Parks, Resorts, Cruise Lines, Marvel, Pixar, Lucasfilm, and Disney Animation Studios.<br/><br/>Areas of interest include, but are not limited to:<ul><li>Embodied Conversational AI including:<ul><li>Speech Processing</li><li>Natural Language Understanding</li><li>Dialogue systems</li><li>Voice Synthesis</li><li>Affective Computing</li><li>Knowledge representation</li><li>Generative Animation</li></ul></li><li>Applications of Data Science and Deep/Machine learning<ul><li>Deep generalists</li><li>Recommender systems</li><li>Robotics, control systems</li><li>Computer vision, including activity and action recognition in videos</li></ul></li><li>Computational Behavioral Science<ul><li>Social psychology</li><li>Cognitive science</li><li>Behavioral econometrics</li><li>Behavior and choice modeling</li></ul></li></ul><div><strong>NOTE: General Posting for Post Doc, Associate Research Scientist, Research Scientist, Sr. Research Scientist</strong><br/> </div></div> <h4>Responsibilities:</h4> <br/>As a researcher at Disney Research Imagineering, you will<ul><li>Conduct advanced research projects in areas of interest to Disney Research and our partnering Business Units</li><li>Closely align and integrate with the Disney business to create value for the company by developing cutting edge technology and impactful demonstrators in the form of hardware and software prototypes and demo systems</li><li>Contribute and deliver to major research projects and platforms of Disney Research</li><li>Keep Disney Research at the forefront of technology research by surveying relevant technologies, attending conferences, reading papers, meeting with technology companies and research labs, and sharing new findings with team members.</li><li>Assist in the hiring and mentoring ...

# %% [markdown]
# ### parse job descriptions

# %%
def break_into_sections(obj):
    html = obj['description']

    bs = BeautifulSoup(
        html,
        features='html.parser'
    )

    ignore_sections = ['Additional Information:']
    job_description_sections = []
    sections = list(map(lambda a: a.text, bs.select('h4')))
    for start, end in zip(sections, [*sections[1:], '-1']):
        if start in ignore_sections:
            continue

        if end != '-1':
            q = f'(?<=<h4>{start}</h4>)(.+?)(<h4>{end}</h4>)'
        else:
            q = f'(?<=<h4>{start}</h4>)(.+)'
        
        match_html = re.search(q, html).group(1)
        match_html = re.sub('<ul>', '\n\n<ul>', match_html)
        match_html = re.sub('</ul>', '</ul>\n\n', match_html)
        match_html = re.sub('<li>', '<li>* ', match_html)
        match_html = re.sub('</li>', '\n</li>', match_html)

        bs2 = BeautifulSoup(
            match_html,
            features='html.parser'
        )

        text = bs2.get_text()
        text = re.sub(r'(\n\n)(\* )([^\n]+)(\n\n)', r'\1\3\n', text)
        job_description_sections.append({
            'section': re.sub(':\s*$', '', start).strip(),
            'text': text.strip()
        })

    return job_description_sections

# %%
headers = []
for item in gosbel_json:
  headers.extend(list(map(lambda a: a['section'], item['sections'])))

set(headers)
# Out:
# {'Basic Qualifications',
#  'Job Summary',
#  'Preferred Education',
#  'Preferred Qualifications',
#  'Required Education',
#  'Responsibilities'}
