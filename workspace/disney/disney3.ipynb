# %%
import re
import os
import json
from collections import Counter
import pandas as pd
import numpy as np

import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import WordNetLemmatizer

nltk.download('stopwords')
nltk.download('omw-1.4')
nltk.download('words')
nltk.download('averaged_perceptron_tagger')
nltk.download('punkt')
nltk.download('maxent_ne_chunker')

import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/danpasse/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/danpasse/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package words to /Users/danpasse/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/danpasse/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to /Users/danpasse/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/danpasse/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!

# %%
documents = []
with open('../../data/disney/imagineering_job_descriptions.json', 'r') as reader:
  for description in json.loads(reader.read()):
    items = [
      item['text']
      for item in description['sections']
      if item['section'] == 'Basic Qualifications' or item['section'] == 'Preferred Qualifications'
    ]

    if len(items) == 0:
      continue

    qualification = {
      'cat_id': description['cat_id'],
      'job_id': description['job_id'],
      'step_1': items
    }

    documents.append(qualification)

documents[0]
# Out:
# {'cat_id': 391,
#  'job_id': 27150045808,
#  'step_1': ['* Familiar with maintaining and creating rigs for CG character animation.\n* Able to provide technical support for computer graphic animation applications.\n* Desired software knowledge/familiarity among: Maya and/or Motion Builder, Adobe Creative Suite, and Shotgun\n* Desired scripting knowledge with languages such as: Python, Mel, C, C++\n* Able to communicate (verbally and in writing) clearly and concisely, regularly keeping stakeholders informed of status, risks, and issues.\n* Able to function in a dynamic work environment, managing multiple project activities.\n* Able to work with limited supervision and to integrate inputs from many individual team members.\n* Have a high tolerance for change and changing requirements.\n* Be a creative problem solver and demonstrate comfort with inventive solutions.\n* Have a valid passport and willing to travel domestically or internationally.',
#   '* Have basic knowledge of mechanical systems, control systems, and/or robotics.\n* Experience with Kuka robotics.\n* Desired knowledge of Tait Navigator software.\n* Experience with motion-capture tools and processes.\n* Familiarity with Unreal Engine and/or Unity, Z-Brush and Solidworks.']}

# %% [markdown]
# ### Step 1

# %%
def transform_text(text):
    text = re.sub(r'(e\.g\.|\/)', ' ', text)
    text = re.sub(r'etc\.', 'etc', text)
    text = re.sub(r'[*•●"()]', ' ', text)
    text = re.sub(r'&', ' and ', text)

    return text

for document in documents:

    document['step_2'] = []
    for section_text in document['step_1']:
        sentences = sent_tokenize(transform_text(section_text))
        tokens = [
            nltk.pos_tag(word_tokenize(sentence))
            for sentence
            in sentences
        ]

        document['step_2'].extend(tokens)

documents[0]['step_2']
# Out:
# [[('Familiar', 'NNP'),
#   ('with', 'IN'),
#   ('maintaining', 'VBG'),
#   ('and', 'CC'),
#   ('creating', 'VBG'),
#   ('rigs', 'NNS'),
#   ('for', 'IN'),
#   ('CG', 'NNP'),
#   ('character', 'NN'),
#   ('animation', 'NN'),
#   ('.', '.')],
#  [('Able', 'JJ'),
#   ('to', 'TO'),
#   ('provide', 'VB'),
#   ('technical', 'JJ'),
#   ('support', 'NN'),
#   ('for', 'IN'),
#   ('computer', 'NN'),
#   ('graphic', 'JJ'),
#   ('animation', 'NN'),
#   ('applications', 'NNS'),
#   ('.', '.')],
#  [('Desired', 'NNP'),
#   ('software', 'NN'),
#   ('knowledge', 'NN'),
#   ('familiarity', 'NN'),
#   ('among', 'IN'),
#   (':', ':'),
#   ('Maya', 'NNP'),
#   ('and', 'CC'),
#   ('or', 'CC'),
#   ('Motion', 'NNP'),
#   ('Builder', 'NNP'),
#   (',', ','),
#   ('Adobe', 'NNP'),
#   ('Creative', 'NNP'),
#   ('Suite', 'NNP'),
#   (',', ','),
#   ('and', 'CC'),
#   ('Shotgun', 'NNP'),
#   ('Desired', 'NNP'),
#   ('scripting', 'VBG'),
#   ('knowledge', 'NN'),
#   ('with', 'IN'),
#   ('languages', 'NNS'),
#   ('such', 'JJ'),
#   ('as', 'IN'),
#   (':', ':'),
#   ('Python', 'NNP'),
#   (',', ','),
#   ('Mel', 'NNP'),
#   (',', ','),
#   ('C', 'NNP'),
#   (',', ','),
#   ('C++', 'NNP'),
#   ('Able', 'NNP'),
#   ('to', 'TO'),
#   ('communicate', 'VB'),
#   ('verbally', 'RB'),
#   ('and', 'CC'),
#   ('in', 'IN'),
#   ('writing', 'VBG'),
#   ('clearly', 'RB'),
#   ('and', 'CC'),
#   ('concisely', 'RB'),
#   (',', ','),
#   ('regularly', 'RB'),
#   ('keeping', 'VBG'),
#   ('stakeholders', 'NNS'),
#   ('informed', 'VBN'),
#   ('of', 'IN'),
#   ('status', 'NN'),
#   (',', ','),
#   ('risks', 'NNS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('issues', 'NNS'),
#   ('.', '.')],
#  [('Able', 'JJ'),
#   ('to', 'TO'),
#   ('function', 'VB'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('dynamic', 'JJ'),
#   ('work', 'NN'),
#   ('environment', 'NN'),
#   (',', ','),
#   ('managing', 'VBG'),
#   ('multiple', 'JJ'),
#   ('project', 'NN'),
#   ('activities', 'NNS'),
#   ('.', '.')],
#  [('Able', 'JJ'),
#   ('to', 'TO'),
#   ('work', 'VB'),
#   ('with', 'IN'),
#   ('limited', 'JJ'),
#   ('supervision', 'NN'),
#   ('and', 'CC'),
#   ('to', 'TO'),
#   ('integrate', 'VB'),
#   ('inputs', 'NNS'),
#   ('from', 'IN'),
#   ('many', 'JJ'),
#   ('individual', 'JJ'),
#   ('team', 'NN'),
#   ('members', 'NNS'),
#   ('.', '.')],
#  [('Have', 'VBP'),
#   ('a', 'DT'),
#   ('high', 'JJ'),
#   ('tolerance', 'NN'),
#   ('for', 'IN'),
#   ('change', 'NN'),
#   ('and', 'CC'),
#   ('changing', 'NN'),
#   ('requirements', 'NNS'),
#   ('.', '.')],
#  [('Be', 'VB'),
#   ('a', 'DT'),
#   ('creative', 'JJ'),
#   ('problem', 'NN'),
#   ('solver', 'NN'),
#   ('and', 'CC'),
#   ('demonstrate', 'VB'),
#   ('comfort', 'NN'),
#   ('with', 'IN'),
#   ('inventive', 'JJ'),
#   ('solutions', 'NNS'),
#   ('.', '.')],
#  [('Have', 'VBP'),
#   ('a', 'DT'),
#   ('valid', 'JJ'),
#   ('passport', 'NN'),
#   ('and', 'CC'),
#   ('willing', 'JJ'),
#   ('to', 'TO'),
#   ('travel', 'VB'),
#   ('domestically', 'RB'),
#   ('or', 'CC'),
#   ('internationally', 'RB'),
#   ('.', '.')],
#  [('Have', 'VBP'),
#   ('basic', 'JJ'),
#   ('knowledge', 'NN'),
#   ('of', 'IN'),
#   ('mechanical', 'JJ'),
#   ('systems', 'NNS'),
#   (',', ','),
#   ('control', 'NN'),
#   ('systems', 'NNS'),
#   (',', ','),
#   ('and', 'CC'),
#   ('or', 'CC'),
#   ('robotics', 'NNS'),
#   ('.', '.')],
#  [('Experience', 'NN'),
#   ('with', 'IN'),
#   ('Kuka', 'NNP'),
#   ('robotics', 'NNS'),
#   ('.', '.')],
#  [('Desired', 'NNP'),
#   ('knowledge', 'NN'),
#   ('of', 'IN'),
#   ('Tait', 'NNP'),
#   ('Navigator', 'NNP'),
#   ('software', 'NN'),
#   ('.', '.')],
#  [('Experience', 'NN'),
#   ('with', 'IN'),
#   ('motion-capture', 'NN'),
#   ('tools', 'NNS'),
#   ('and', 'CC'),
#   ('processes', 'NNS'),
#   ('.', '.')],
#  [('Familiarity', 'NN'),
#   ('with', 'IN'),
#   ('Unreal', 'NNP'),
#   ('Engine', 'NNP'),
#   ('and', 'CC'),
#   ('or', 'CC'),
#   ('Unity', 'NNP'),
#   (',', ','),
#   ('Z-Brush', 'NNP'),
#   ('and', 'CC'),
#   ('Solidworks', 'NNP'),
#   ('.', '.')]]

# %% [markdown]
# ### Step 2

# %%
## tag strings

grammar = r"""
  CLAUSE: {<DT>?<JJ.*>*<NN.*>}           # Chunk NP, VP
"""

cp = nltk.RegexpParser(grammar)

for document in documents:

    document['step_3'] = []
    for sentence in document['step_2']:
        chunks = cp.parse(sentence)
        for subtree in chunks.subtrees():
            if subtree.label() == 'CLAUSE':
                print(subtree)

documents[0]['step_3']
# Out:
# (CLAUSE character/NN animation/NN)
# (CLAUSE technical/JJ support/NN)
# (CLAUSE computer/NN)
# (CLAUSE graphic/JJ animation/NN)
# (CLAUSE software/NN knowledge/NN familiarity/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE status/NN)
# (CLAUSE dynamic/JJ work/NN environment/NN)
# (CLAUSE multiple/JJ project/NN)
# (CLAUSE limited/JJ supervision/NN)
# (CLAUSE many/JJ individual/JJ team/NN)
# (CLAUSE high/JJ tolerance/NN)
# (CLAUSE change/NN)
# (CLAUSE changing/NN)
# (CLAUSE creative/JJ problem/NN solver/NN)
# (CLAUSE comfort/NN)
# (CLAUSE valid/JJ passport/NN)
# (CLAUSE basic/JJ knowledge/NN)
# (CLAUSE control/NN)
# (CLAUSE Experience/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE software/NN)
# (CLAUSE Experience/NN)
# (CLAUSE motion-capture/NN)
# (CLAUSE Familiarity/NN)
# (CLAUSE year/NN)
# (CLAUSE experience/NN)
# (CLAUSE interior/JJ design/NN practice/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE experience/NN)
# (CLAUSE practice/NN)
# (CLAUSE interior/JJ design/NN)
# (CLAUSE verbal/JJ communication/NN)
# (CLAUSE thoughtful/JJ design/NN)
# (CLAUSE ability/NN)
# (CLAUSE problem/NN solve/NN)
# (CLAUSE proficiency/NN)
# (CLAUSE digital/JJ drafting/NN)
# (CLAUSE illustration/NN)
# (CLAUSE minimum/NN)
# (CLAUSE related/JJ experience/NN)
# (CLAUSE leadership/NN experience/NN)
# (CLAUSE film/NN theater/NN production/NN)
# (CLAUSE self-starter/NN)
# (CLAUSE ability/NN)
# (CLAUSE strong/JJ interest/NN)
# (CLAUSE landscape/NN)
# (CLAUSE direction/NN)
# (CLAUSE adapt/NN)
# (CLAUSE work/NN)
# (CLAUSE team/NN environment/NN)
# (CLAUSE conflict/NN)
# (CLAUSE guide/NN team/NN)
# (CLAUSE client/NN relationship/NN)
# (CLAUSE day/NN)
# (CLAUSE week/NN)
# (CLAUSE business/NN)
# (CLAUSE 8-10/JJ year/NN)
# (CLAUSE experience/NN)
# (CLAUSE similar/JJ working/NN)
# (CLAUSE game/NN pipeline/NN)
# (CLAUSE scripting/NN)
# (CLAUSE development/NN experience/NN)
# (CLAUSE experience/NN)
# (CLAUSE proficiency/NN)
# (CLAUSE emphasis/NN)
# (CLAUSE packaging/NN deployment/NN custom/NN user/NN)
# (CLAUSE asset/NN)
# (CLAUSE adaptability/NN)
# (CLAUSE willingness/NN)
# (CLAUSE experience/NN)
# (CLAUSE content/NN development/NN)
# (CLAUSE development/NN)
# (CLAUSE engine/NN development/NN game/NN logic/NN)
# (CLAUSE plugin/NN)
# (CLAUSE core/NN engine/NN experience/NN)
# (CLAUSE software/NN)
# (CLAUSE prototyping/NN)
# (CLAUSE experience/NN)
# (CLAUSE jQuery/NN)
# (CLAUSE cross-platform/NN software/NN)
# (CLAUSE math/NN)
# (CLAUSE computer/NN)
# (CLAUSE experience/NN)
# (CLAUSE experience/NN)
# (CLAUSE simulation/NN)
# (CLAUSE content/JJ creation/NN software/NN)
# (CLAUSE etc/NN)
# (CLAUSE Ability/NN)
# (CLAUSE organization/NN)
# (CLAUSE ability/NN)
# (CLAUSE multi-task/NN)
# (CLAUSE Extensive/JJ knowledge/NN)
# (CLAUSE Double-checking/NN)
# (CLAUSE cost/NN control/NN)
# (CLAUSE engineering/NN experience/NN)
# (CLAUSE experience/NN)
# (CLAUSE similar/JJ facility/NN)
# (CLAUSE construction/NN)
# (CLAUSE supervisory/JJ experience/NN)
# (CLAUSE outside/JJ field/NN experience/NN)
# (CLAUSE applicable/JJ site/NN development/NN)
# (CLAUSE resort/NN development/NN)
# (CLAUSE organization/NN)
# (CLAUSE relationship/NN building/NN)
# (CLAUSE collaborate/NN)
# (CLAUSE Technical/JJ experience/NN)
# (CLAUSE expertise/NN)
# (CLAUSE construction/NN field/NN)
# (CLAUSE construction/NN)
# (CLAUSE project/NN)
# (CLAUSE software/NN)
# (CLAUSE intended/JJ project/NN)
# (CLAUSE etc/NN)
# (CLAUSE project/NN field/NN experience/NN relevant/NN)
# (CLAUSE area/NN)
# (CLAUSE Structural/JJ engineering/NN design/NN)
# (CLAUSE analysis/NN experience/NN)
# (CLAUSE concrete/NN)
# (CLAUSE steel/NN)
# (CLAUSE wood/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE structural/JJ engineering/NN discipline/NN)
# (CLAUSE industry/NN)
# (CLAUSE construction/NN)
# (CLAUSE current/JJ technology/NN)
# (CLAUSE preparation/NN)
# (CLAUSE use/NN)
# (CLAUSE contract/NN)
# (CLAUSE design/NN)
# (CLAUSE construction/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE design/NN technology/NN)
# (CLAUSE detailed/JJ familiarity/NN)
# (CLAUSE structural/JJ design/NN)
# (CLAUSE analysis/NN computer/NN)
# (CLAUSE Ability/NN)
# (CLAUSE minor/JJ supervision/NN)
# (CLAUSE multi-discipline/JJ project/NN team/NN environment/NN)
# (CLAUSE Ability/NN)
# (CLAUSE team/NN)
# (CLAUSE production/NN)
# (CLAUSE construction/NN)
# (CLAUSE design/NN)
# (CLAUSE oral/JJ communication/NN)
# (CLAUSE Professional/JJ registration/NN)
# (CLAUSE field/NN)
# (CLAUSE engineering/NN)
# (CLAUSE minimum/NN)
# (CLAUSE year/NN)
# (CLAUSE licensed/JJ experience/NN)
# (CLAUSE field/NN)
# (CLAUSE Experienced/JJ theme/NN park/NN attraction/NN design/NN)
# (CLAUSE construction/NN)
# (CLAUSE relevant/JJ experience/NN)
# (CLAUSE business/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE complex/JJ brand/NN s/NN)
# (CLAUSE expert/JJ ability/NN)
# (CLAUSE brand/NN)
# (CLAUSE business-leading/JJ growth/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE travel/NN)
# (CLAUSE tourism/NN)
# (CLAUSE entertainment/NN)
# (CLAUSE leisure/NN)
# (CLAUSE confident/JJ creative/JJ sensibility/NN)
# (CLAUSE business/NN)
# (CLAUSE success/NN)
# (CLAUSE strategic/JJ planning/NN)
# (CLAUSE business/NN)
# (CLAUSE budget/NN management/NN)
# (CLAUSE global/JJ level/NN)
# (CLAUSE integration/NN)
# (CLAUSE understanding/NN)
# (CLAUSE delivery/NN process/NN)
# (CLAUSE particular/JJ new/JJ product/NN)
# (CLAUSE industry/NN)
# (CLAUSE communication/NN)
# (CLAUSE formal/JJ speech/NN presentation/NN)
# (CLAUSE strong/JJ executive/NN presence/NN)
# (CLAUSE storytelling/NN)
# (CLAUSE communication/NN skill/NN)
# (CLAUSE compelling/JJ vision/NN)
# (CLAUSE builder/NN)
# (CLAUSE matrix/NN)
# (CLAUSE Positive/JJ attitude/NN)
# (CLAUSE proven/JJ ability/NN)
# (CLAUSE energized/JJ environment/NN)
# (CLAUSE manager/NN)
# (CLAUSE work/NN)
# (CLAUSE high/JJ level/NN output/NN)
# (CLAUSE business/NN)
# (CLAUSE high/JJ level/NN)
# (CLAUSE execute/NN)
# (CLAUSE tactical/JJ level/NN)
# (CLAUSE engineering/NN construction/NN planning/NN)
# (CLAUSE scheduling/NN)
# (CLAUSE entertainment/NN)
# (CLAUSE coordination/NN experience/NN)
# (CLAUSE combination/NN)
# (CLAUSE experience/NN)
# (CLAUSE software/NN)
# (CLAUSE construction/NN)
# (CLAUSE production/NN)
# (CLAUSE design/NN experience/NN)
# (CLAUSE Good/JJ understanding/NN)
# (CLAUSE practical/JJ project/NN)
# (CLAUSE value/NN measurement/NN)
# (CLAUSE Prefer/NN)
# (CLAUSE course/NN)
# (CLAUSE experience/NN)
# (CLAUSE Prior/JJ supervisory/JJ experience/NN)
# (CLAUSE junior/JJ staff/NN)
# (CLAUSE experience/NN)
# (CLAUSE Theme/NN)
# (CLAUSE show/NN)
# (CLAUSE ride/JJ product/NN)
# (CLAUSE engineering/NN construction/NN planning/NN)
# (CLAUSE scheduling/NN)
# (CLAUSE entertainment/NN)
# (CLAUSE coordination/NN experience/NN)
# (CLAUSE combination/NN)
# (CLAUSE experience/NN)
# (CLAUSE software/NN)
# (CLAUSE construction/NN)
# (CLAUSE production/NN)
# (CLAUSE design/NN experience/NN)
# (CLAUSE Good/JJ understanding/NN)
# (CLAUSE practical/JJ project/NN)
# (CLAUSE value/NN measurement/NN)
# (CLAUSE Prefer/NN)
# (CLAUSE course/NN)
# (CLAUSE experience/NN)
# (CLAUSE Prior/JJ supervisory/JJ experience/NN)
# (CLAUSE junior/JJ staff/NN)
# (CLAUSE experience/NN)
# (CLAUSE Theme/NN)
# (CLAUSE show/NN)
# (CLAUSE ride/JJ product/NN)
# (CLAUSE engineering/NN construction/NN planning/NN)
# (CLAUSE scheduling/NN)
# (CLAUSE entertainment/NN)
# (CLAUSE coordination/NN experience/NN)
# (CLAUSE combination/NN)
# (CLAUSE experience/NN)
# (CLAUSE software/NN)
# (CLAUSE production/NN)
# (CLAUSE design/NN experience/NN)
# (CLAUSE graphical/JJ program/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE ability/NN)
# (CLAUSE basic/JJ understanding/NN)
# (CLAUSE design/NN)
# (CLAUSE construction/NN progress/NN measurement/NN)
# (CLAUSE value/NN measurement/NN)
# (CLAUSE Work/NN experience/NN)
# (CLAUSE Theme/NN)
# (CLAUSE show/NN)
# (CLAUSE ride/JJ product/NN)
# (CLAUSE engineering/NN construction/NN planning/NN)
# (CLAUSE scheduling/NN)
# (CLAUSE entertainment/NN)
# (CLAUSE coordination/NN experience/NN)
# (CLAUSE combination/NN)
# (CLAUSE experience/NN)
# (CLAUSE software/NN)
# (CLAUSE construction/NN)
# (CLAUSE production/NN)
# (CLAUSE design/NN experience/NN)
# (CLAUSE Good/JJ understanding/NN)
# (CLAUSE practical/JJ project/NN)
# (CLAUSE value/NN measurement/NN)
# (CLAUSE Prefer/NN)
# (CLAUSE course/NN)
# (CLAUSE experience/NN)
# (CLAUSE Prior/JJ supervisory/JJ experience/NN)
# (CLAUSE junior/JJ staff/NN)
# (CLAUSE experience/NN)
# (CLAUSE Theme/NN)
# (CLAUSE show/NN)
# (CLAUSE ride/JJ product/NN)
# (CLAUSE outside/JJ field/NN experience/NN)
# (CLAUSE applicable/JJ site/NN development/NN)
# (CLAUSE resort/NN development/NN)
# (CLAUSE organization/NN)
# (CLAUSE relationship/NN building/NN)
# (CLAUSE collaborate/NN)
# (CLAUSE Technical/JJ experience/NN)
# (CLAUSE expertise/NN)
# (CLAUSE construction/NN field/NN)
# (CLAUSE construction/NN)
# (CLAUSE project-related/JJ software/NN)
# (CLAUSE intended/JJ project/NN)
# (CLAUSE management/NN document/NN control/NN)
# (CLAUSE management/NN)
# (CLAUSE software/NN knowledge/NN)
# (CLAUSE scheduling/NN)
# (CLAUSE project/NN field/NN experience/NN relevant/NN)
# (CLAUSE area/NN)
# (CLAUSE electrical/JJ background/NN)
# (CLAUSE experience/NN)
# (CLAUSE backbone/NN cable/NN)
# (CLAUSE optic/JJ installation/NN)
# (CLAUSE outside/JJ field/NN experience/NN)
# (CLAUSE applicable/JJ site/NN development/NN)
# (CLAUSE resort/NN development/NN)
# (CLAUSE organization/NN)
# (CLAUSE relationship/NN building/NN)
# (CLAUSE collaborate/NN)
# (CLAUSE Technical/JJ experience/NN)
# (CLAUSE expertise/NN)
# (CLAUSE construction/NN field/NN)
# (CLAUSE construction/NN)
# (CLAUSE project/NN)
# (CLAUSE software/NN)
# (CLAUSE intended/JJ project/NN)
# (CLAUSE etc/NN)
# (CLAUSE project/NN field/NN experience/NN relevant/NN)
# (CLAUSE area/NN)
# (CLAUSE experience/NN)
# (CLAUSE mechanical/JJ design/NN engineer/NN)
# (CLAUSE mechanical/JJ design/NN experience/NN)
# (CLAUSE industry/NN)
# (CLAUSE designing/NN)
# (CLAUSE building/NN complex/NN)
# (CLAUSE experience/NN)
# (CLAUSE mastery/NN)
# (CLAUSE experience/NN)
# (CLAUSE ability/NN)
# (CLAUSE prototype/NN level/NN)
# (CLAUSE manufacturing/NN)
# (CLAUSE milling/NN)
# (CLAUSE flexibility/NN)
# (CLAUSE adaptability/NN)
# (CLAUSE team/NN)
# (CLAUSE prototyping/NN)
# (CLAUSE playtesting/NN)
# (CLAUSE strategy/NN)
# (CLAUSE Experience/NN)
# (CLAUSE fabrication/NN)
# (CLAUSE clear/JJ direction/NN)
# (CLAUSE feedback/NN)
# (CLAUSE other/JJ team/NN)
# (CLAUSE environment/NN)
# (CLAUSE desire/NN)
# (CLAUSE Experience/NN)
# (CLAUSE actuator/NN design/NN)
# (CLAUSE motor/NN selection/NN)
# (CLAUSE science/NN)
# (CLAUSE metallurgy/JJ experience/NN)
# (CLAUSE designing/NN)
# (CLAUSE surface/NN)
# (CLAUSE kinematic/JJ motion/NN analysis/NN)
# (CLAUSE experience/NN Experience/NN)
# (CLAUSE tolerance/NN)
# (CLAUSE stack-up/JJ analysis/NN)
# (CLAUSE metal/NN)
# (CLAUSE weldment/NN design/NN)
# (CLAUSE administration/NN)
# (CLAUSE configuration/NN)
# (CLAUSE roll-out/JJ experience/NN)
# (CLAUSE design/NN experience/NN)
# (CLAUSE ability/NN)
# (CLAUSE aesthetic/JJ form/NN)
# (CLAUSE function/NN)
# (CLAUSE Portfolio/NN)
# (CLAUSE strong/JJ design/NN)
# (CLAUSE well-developed/JJ sense/NN)
# (CLAUSE mock-ups/NN)
# (CLAUSE production/NN)
# (CLAUSE ability/NN)
# (CLAUSE idea/NN)
# (CLAUSE technological/JJ development/NN)
# (CLAUSE service/NN)
# (CLAUSE magic/NN)
# (CLAUSE broad/JJ understanding/NN)
# (CLAUSE comfort/NN)
# (CLAUSE enthusiasm/NN)
# (CLAUSE technology/NN)
# (CLAUSE ability/NN)
# (CLAUSE design/NN)
# (CLAUSE productivity/NN)
# (CLAUSE code/NN)
# (CLAUSE Strong/JJ presentation/NN)
# (CLAUSE professional/JJ writing/NN)
# (CLAUSE flexibility/NN)
# (CLAUSE Excellent/JJ time/NN management/NN)
# (CLAUSE adaptability/NN)
# (CLAUSE innovation/NN environment/NN)
# (CLAUSE Proficiency/NN)
# (CLAUSE software/NN prototyping/NN)
# (CLAUSE game/NN)
# (CLAUSE Experience/NN)
# (CLAUSE hardware/NN)
# (CLAUSE surface/NN modeling/NN)
# (CLAUSE animation/NN)
# (CLAUSE design/NN)
# (CLAUSE fabrication/NN)
# (CLAUSE signage/NN)
# (CLAUSE setwork/NN carpentry/NN)
# (CLAUSE printing/NN)
# (CLAUSE solid/JJ surface/NN modeling/NN)
# (CLAUSE laser/NN cutting/NN)
# (CLAUSE outside/JJ job/NN)
# (CLAUSE related/JJ experience/NN)
# (CLAUSE coordination/NN experience/NN)
# (CLAUSE project/NN team/NN)
# (CLAUSE conflict/NN)
# (CLAUSE complexity/NN)
# (CLAUSE adapt/NN)
# (CLAUSE collaborate/NN)
# (CLAUSE consensus/NN)
# (CLAUSE anticipate/NN)
# (CLAUSE level/NN)
# (CLAUSE respect/NN)
# (CLAUSE professionalism/NN)
# (CLAUSE Project/NN environment/NN)
# (CLAUSE strong/JJ depth/NN)
# (CLAUSE character/NN)
# (CLAUSE social/JJ excellence/NN)
# (CLAUSE required/JJ daily/JJ interface/NN)
# (CLAUSE etc/NN)
# (CLAUSE Understanding/NN)
# (CLAUSE scheduling/NN)
# (CLAUSE budgeting/NN)
# (CLAUSE quality/NN control/NN)
# (CLAUSE desktop/NN)
# (CLAUSE mobile/JJ iPad/NN)
# (CLAUSE desktop/NN)
# (CLAUSE mobile/JJ iPad/NN)
# (CLAUSE desktop/NN)
# (CLAUSE mobile/JJ iPad/NN)
# (CLAUSE project/NN management/NN software/NN)
# (CLAUSE job/NN)
# (CLAUSE related/JJ field/NN experience/NN)
# (CLAUSE applicable/JJ site/NN development/NN)
# (CLAUSE resort/NN development/NN)
# (CLAUSE Emphasis/NN)
# (CLAUSE plumbing/NN)
# (CLAUSE management/NN)
# (CLAUSE field/NN)
# (CLAUSE operator/NN)
# (CLAUSE Manage/NN)
# (CLAUSE complex/JJ construction/NN site/NN)
# (CLAUSE technical/JJ expertise/NN)
# (CLAUSE construction/NN)
# (CLAUSE adherence/NN)
# (CLAUSE quality/NN)
# (CLAUSE successful/JJ completion/NN)
# (CLAUSE time/NN)
# (CLAUSE budget/NN)
# (CLAUSE client/NN quality/NN)
# (CLAUSE management/NN ability/NN)
# (CLAUSE Manage/NN)
# (CLAUSE Project/NN environment/NN)
# (CLAUSE depth/NN)
# (CLAUSE character/NN)
# (CLAUSE social/JJ excellence/NN)
# (CLAUSE daily/JJ partnership/NN)
# (CLAUSE etc/NN)
# (CLAUSE Entry-level/JJ software/NN product/NN management/NN)
# (CLAUSE second-hand/JJ experience/NN)
# (CLAUSE entertainment/NN)
# (CLAUSE technology/NN)
# (CLAUSE Strong/JJ communication/NN)
# (CLAUSE Strong/JJ passion/NN)
# (CLAUSE excellence/NN)
# (CLAUSE software/NN development/NN)
# (CLAUSE product/NN rigor/NN)
# (CLAUSE Familiarity/NN)
# (CLAUSE specific/JJ domain/NN)
# (CLAUSE management/NN)
# (CLAUSE architecture/NN)
# (CLAUSE design/NN)
# (CLAUSE gaming/NN)
# (CLAUSE mechanical/JJ engineering/NN)
# (CLAUSE ability/NN)
# (CLAUSE verbal/JJ communication/NN)
# (CLAUSE multi-disciplinary/JJ team/NN environment/NN)
# (CLAUSE specific/JJ application/NN)
# (CLAUSE construction/NN documentation/NN)
# (CLAUSE ability/NN)
# (CLAUSE detail/NN)
# (CLAUSE contract/NN documentation/NN)
# (CLAUSE direction/NN)
# (CLAUSE Familiarity/NN)
# (CLAUSE documentation/NN)
# (CLAUSE commitment/NN)
# (CLAUSE high/JJ quality/NN work/NN)
# (CLAUSE ability/NN)
# (CLAUSE digital/JJ illustration/NN)
# (CLAUSE verbal/JJ communication/NN)
# (CLAUSE multi-disciplinary/JJ team/NN environment/NN)
# (CLAUSE specific/JJ application/NN)
# (CLAUSE construction/NN documentation/NN)
# (CLAUSE ability/NN)
# (CLAUSE detail/NN)
# (CLAUSE contract/NN documentation/NN)
# (CLAUSE direction/NN)
# (CLAUSE design/NN)
# (CLAUSE sign/NN construction/NN)
# (CLAUSE architecture/NN)
# (CLAUSE interior/JJ design/NN)
# (CLAUSE landscape/NN design/NN)
# (CLAUSE design/JJ construction-related/JJ industry/NN)
# (CLAUSE team/NN)
# (CLAUSE strategic/JJ agility/NN)
# (CLAUSE ability/NN)
# (CLAUSE oral/JJ communication/NN)
# (CLAUSE Strong/JJ negotiation/NN)
# (CLAUSE team/NN environment/NN)
# (CLAUSE customer/NN focus/NN)
# (CLAUSE excellent/JJ internal/JJ client/NN support/NN)
# (CLAUSE desire/NN)
# (CLAUSE ever-changing/JJ environment/NN)
# (CLAUSE ambiguity/NN)
# (CLAUSE entertainment/NN industry/NN)
# (CLAUSE design/NN)
# (CLAUSE construction/NN)
# (CLAUSE service/NN)
# (CLAUSE change/NN)
# (CLAUSE experience/NN)
# (CLAUSE legal/JJ department/NN)
# (CLAUSE boilerplate/NN)
# (CLAUSE company/NN)
# (CLAUSE proficiency/NN)
# (CLAUSE position/NN)
# (CLAUSE 5-10/JJ %/NN travel/NN)
# (CLAUSE experience/NN)
# (CLAUSE related/JJ practice/NN)
# (CLAUSE design/NN background/NN)
# (CLAUSE experience/NN)
# (CLAUSE print/NN)
# (CLAUSE complex/JJ information/NN)
# (CLAUSE translate/NN)
# (CLAUSE wide/JJ audience/NN)
# (CLAUSE thoughtful/JJ design/NN)
# (CLAUSE color/NN theory/NN)
# (CLAUSE judgment/NN)
# (CLAUSE layout/NN)
# (CLAUSE hierarchy/NN)
# (CLAUSE mastery/NN)
# (CLAUSE worker/NN)
# (CLAUSE other/JJ team/NN)
# (CLAUSE content/NN)
# (CLAUSE diverse/JJ team/NN environment/NN)
# (CLAUSE core/NN)
# (CLAUSE project/NN)
# (CLAUSE high-level/JJ understanding/NN)
# (CLAUSE piece/NN)
# (CLAUSE information/NN)
# (CLAUSE creative/JJ thinker/NN)
# (CLAUSE understanding/NN)
# (CLAUSE information/NN)
# (CLAUSE data/NN storytelling/NN)
# (CLAUSE Experience/NN)
# (CLAUSE office/NN)
# (CLAUSE basic/JJ business/NN)
# (CLAUSE problem-solving/NN)
# (CLAUSE strategic/JJ thinking/NN)
# (CLAUSE experience/NN)
# (CLAUSE administrative/JJ support/NN role/NN)
# (CLAUSE baseline/JJ emotional/JJ intelligence/NN)
# (CLAUSE verbal/JJ communication/NN)
# (CLAUSE composure/NN)
# (CLAUSE high/JJ pressure/NN)
# (CLAUSE room/NN ”/NN)
# (CLAUSE attention/NN)
# (CLAUSE trust/NN)
# (CLAUSE customer/NN service/NN)
# (CLAUSE professionalism/NN)
# (CLAUSE punctuality/NN)
# (CLAUSE reliability/NN)
# (CLAUSE engage/NN)
# (CLAUSE equal/JJ level/NN)
# (CLAUSE respect/NN)
# (CLAUSE composure/NN)
# (CLAUSE studio/NN)
# (CLAUSE pipeline/NN)
# (CLAUSE self/NN)
# (CLAUSE studio/NN education/NN)
# (CLAUSE work/NN)
# (CLAUSE administrative/JJ experience/NN)
# (CLAUSE executive/NN)
# (CLAUSE environment/NN)
# (CLAUSE technology/NN)
# (CLAUSE role/NN)
# (CLAUSE quick/JJ learner/NN)
# (CLAUSE industry/NN experience/NN)
# (CLAUSE network/NN)
# (CLAUSE understanding/NN)
# (CLAUSE presentation/NN building/NN experience/NN)
# (CLAUSE engage/NN)
# (CLAUSE equal/JJ level/NN)
# (CLAUSE respect/NN)
# (CLAUSE composure/NN)
# (CLAUSE studio/NN)
# (CLAUSE pipeline/NN)
# (CLAUSE self/NN)
# (CLAUSE studio/NN education/NN)
# (CLAUSE experience/NN)
# (CLAUSE software/NN development/NN)
# (CLAUSE same/JJ domain/NN)
# (CLAUSE experience/NN)
# (CLAUSE modern/JJ software/NN development/NN)
# (CLAUSE version/NN control/NN)
# (CLAUSE workflow/JJ management/NN)
# (CLAUSE experience/NN)
# (CLAUSE process/NN control/NN)
# (CLAUSE engineering/NN industry/NN)
# (CLAUSE Prior/JJ experience/NN authoring/NN)
# (CLAUSE motion/NN control/NN software/NN)
# (CLAUSE Demonstrable/JJ technical/JJ writing/NN)
# (CLAUSE documentation/NN)
# (CLAUSE communication/NN)
# (CLAUSE behalf/NN)
# (CLAUSE company/NN)
# (CLAUSE business/NN)
# (CLAUSE relocation/NN)
# (CLAUSE month/NN)
# (CLAUSE year/NN stay/NN)
# (CLAUSE Experience/NN)
# (CLAUSE IEC61131-3/JJ programming/NN)
# (CLAUSE sACN/NN)
# (CLAUSE Familiarity/NN)
# (CLAUSE experience/NN)
# (CLAUSE strong/JJ plus/NN)
# (CLAUSE experience/NN)
# (CLAUSE software/NN development/NN)
# (CLAUSE same/JJ domain/NN)
# (CLAUSE experience/NN)
# (CLAUSE modern/JJ software/NN development/NN)
# (CLAUSE version/NN control/NN)
# (CLAUSE workflow/JJ management/NN)
# (CLAUSE experience/NN)
# (CLAUSE process/NN control/NN)
# (CLAUSE engineering/NN industry/NN)
# (CLAUSE Prior/JJ experience/NN authoring/NN)
# (CLAUSE motion/NN control/NN software/NN)
# (CLAUSE Demonstrable/JJ technical/JJ writing/NN)
# (CLAUSE documentation/NN)
# (CLAUSE communication/NN)
# (CLAUSE behalf/NN)
# (CLAUSE company/NN)
# (CLAUSE business/NN)
# (CLAUSE relocation/NN)
# (CLAUSE month/NN)
# (CLAUSE year/NN stay/NN)
# (CLAUSE Experience/NN)
# (CLAUSE IEC61131-3/JJ programming/NN)
# (CLAUSE sACN/NN)
# (CLAUSE Familiarity/NN)
# (CLAUSE experience/NN)
# (CLAUSE strong/JJ plus/NN)
# (CLAUSE experience/NN)
# (CLAUSE related/JJ professional/JJ environment/NN)
# (CLAUSE Previous/JJ experience/NN)
# (CLAUSE Proficiency/NN)
# (CLAUSE use/NN)
# (CLAUSE standard/JJ theatrical/JJ documentation/NN focus/NN)
# (CLAUSE fixture/NN)
# (CLAUSE dimmer/NN control/NN)
# (CLAUSE understanding/NN)
# (CLAUSE light/JJ focus/NN)
# (CLAUSE color/NN)
# (CLAUSE texture/NN)
# (CLAUSE highlight/NN)
# (CLAUSE shadow/NN)
# (CLAUSE advanced/JJ understanding/NN)
# (CLAUSE electrical/JJ configuration/NN)
# (CLAUSE control/NN)
# (CLAUSE infrastructure/NN)
# (CLAUSE lighting/NN designer/NN assistant/NN)
# (CLAUSE theatrical/NN)
# (CLAUSE environmental/JJ nature/NN)
# (CLAUSE product/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE facility/NN)
# (CLAUSE integration/NN)
# (CLAUSE specific/JJ discipline/NN)
# (CLAUSE attraction/NN Understanding/NN)
# (CLAUSE creative/JJ process/NN)
# (CLAUSE development/NN)
# (CLAUSE creative/JJ design/NN)
# (CLAUSE development/NN)
# (CLAUSE schedule/NN)
# (CLAUSE high/JJ pressure/NN environment/NN)
# (CLAUSE strict/JJ schedule/NN)
# (CLAUSE ownership/NN)
# (CLAUSE accept/JJ responsibility/NN)
# (CLAUSE product/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE field/NN)
# (CLAUSE content/JJ creation/NN)
# (CLAUSE experience/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE game/NN engine/NN use/NN)
# (CLAUSE software/NN)
# (CLAUSE previsualization/NN)
# (CLAUSE creation/NN)
# (CLAUSE eye/NN)
# (CLAUSE experience/NN)
# (CLAUSE industry/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE theme/NN)
# (CLAUSE production/NN)
# (CLAUSE pipeline/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE projection/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE audio/JJ source/NN)
# (CLAUSE reproduction/NN exhibition/NN technology/NN)
# (CLAUSE Understanding/NN)
# (CLAUSE sound/NN system/NN design/NN)
# (CLAUSE test/NN)
# (CLAUSE measurement/NN)
# (CLAUSE Experience/NN)
# (CLAUSE PC/NN)
# (CLAUSE hardware/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE reproduction/NN exhibition/NN technology/NN)
# (CLAUSE industry/NN audio/NN)
# (CLAUSE video/NN)
# (CLAUSE audio/JJ amplifier/NN design/NN)
# (CLAUSE direct/JJ drive/NN)
# (CLAUSE distribution/NN)
# (CLAUSE video/NN)
# (CLAUSE hi-def/NN)
# (CLAUSE cinema/NN)
# (CLAUSE distribution/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE theatrical/JJ design/NN)
# (CLAUSE technical/JJ knowledge/NN)
# (CLAUSE specific/JJ discipline/NN)
# (CLAUSE construction/NN)
# (CLAUSE design/NN)
# (CLAUSE creative/JJ process/NN)
# (CLAUSE development/NN)
# (CLAUSE creative/JJ design/NN)
# (CLAUSE Ability/NN)
# (CLAUSE manner/NN)
# (CLAUSE translator/NN)
# (CLAUSE clean/JJ sheet/NN design/NN)
# (CLAUSE integration/NN experience/NN)
# (CLAUSE analysis/NN)
# (CLAUSE simulation/NN)
# (CLAUSE Understanding/NN)
# (CLAUSE computer/NN)
# (CLAUSE power/NN)
# (CLAUSE manner/NN)
# (CLAUSE design/NN)
# (CLAUSE technology/NN)
# (CLAUSE experience/NN)
# (CLAUSE experience/NN)
# (CLAUSE software/NN)
# (CLAUSE translator/NN)
# (CLAUSE clean/JJ sheet/NN design/NN)
# (CLAUSE integration/NN experience/NN)
# (CLAUSE analysis/NN)
# (CLAUSE simulation/NN)
# (CLAUSE year/NN experience/NN)
# (CLAUSE financial/JJ analysis/NN)
# (CLAUSE business/NN management/NN role/NN)
# (CLAUSE excel/NN)
# (CLAUSE experience/NN)
# (CLAUSE demonstrated/JJ analytical/JJ decision-making/NN)
# (CLAUSE ability/NN)
# (CLAUSE communication/NN)
# (CLAUSE demonstrated/JJ ability/NN)
# (CLAUSE compelling/NN)
# (CLAUSE influential/JJ business/NN)
# (CLAUSE fast-paced/JJ environment/NN)
# (CLAUSE environment/NN)
# (CLAUSE passion/NN)
# (CLAUSE technology/NN)
# (CLAUSE professional/JJ experience/NN)
# (CLAUSE behalf/NN)
# (CLAUSE company/NN)
# (CLAUSE language/NN)
# (CLAUSE experience/NN)
# (CLAUSE writing/NN)
# (CLAUSE competent/NN)
# (CLAUSE competent/NN)
# (CLAUSE safety/NN timing/NN analysis/NN)
# (CLAUSE experience/NN)
# (CLAUSE experience/NN)
# (CLAUSE servo/NN)
# (CLAUSE time/NN)
# (CLAUSE relevant/JJ experience/NN)
# (CLAUSE complex/JJ control/NN)
# (CLAUSE software/NN)
# (CLAUSE methodology/NN)
# (CLAUSE broad/JJ understanding/NN)
# (CLAUSE technology/NN)
# (CLAUSE time/NN)
# (CLAUSE communication/NN)
# (CLAUSE Proficiency/NN)
# (CLAUSE eQUEST/NN)
# (CLAUSE other/JJ energy/NN)
# (CLAUSE software/NN)
# (CLAUSE storm/NN)
# (CLAUSE water/NN)
# (CLAUSE gas/NN)
# (CLAUSE proficiency/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE mechanical/JJ engineering/NN discipline/NN)
# (CLAUSE facility/NN design/NN)
# (CLAUSE construction/NN)
# (CLAUSE campus/NN piping/NN network/NN design/NN)
# (CLAUSE design/NN)
# (CLAUSE engineering/NN)
# (CLAUSE system/NN)
# (CLAUSE design/NN)
# (CLAUSE construction/NN)
# (CLAUSE Proficiency/NN)
# (CLAUSE current/JJ technology/NN)
# (CLAUSE preparation/NN)
# (CLAUSE use/NN)
# (CLAUSE contract/NN)
# (CLAUSE design/NN)
# (CLAUSE construction/NN administration/NN)
# (CLAUSE industrial/JJ design/NN)
# (CLAUSE water/NN treatment/NN)
# (CLAUSE process/NN)
# (CLAUSE industry/NN)
# (CLAUSE sustainability/NN)
# (CLAUSE carbon/NN footprint/NN)
# (CLAUSE facility/NN efficiency/NN)
# (CLAUSE communication/NN)
# (CLAUSE Experience/NN)
# (CLAUSE control/NN diagrams/NN)
# (CLAUSE sequence/NN)
# (CLAUSE life/NN cycle/NN analysis/NN)
# (CLAUSE basis/NN)
# (CLAUSE energy/NN use/NN)
# (CLAUSE first/JJ cost/NN)
# (CLAUSE life/NN expectancy/NN)
# (CLAUSE membership/NN)
# (CLAUSE role…/NN)
# (CLAUSE basic/JJ knowledge/NN)
# (CLAUSE design/NN process/NN)
# (CLAUSE Previous/JJ experience/NN)
# (CLAUSE creative/JJ environment/NN)
# (CLAUSE thorough/JJ communication/NN)
# (CLAUSE email/NN)
# (CLAUSE person/NN)
# (CLAUSE self-starter/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE team/NN environment/NN)
# (CLAUSE valid/JJ driver/NN)
# (CLAUSE s/NN license/NN)
# (CLAUSE role…/NN Experience/NN)
# (CLAUSE thoughtful/JJ design/NN)
# (CLAUSE professional/JJ judgment/NN)
# (CLAUSE signage/NN design/NN)
# (CLAUSE Theme/NN)
# (CLAUSE design/NN)
# (CLAUSE illustration/NN)
# (CLAUSE graphic/JJ design/NN experience/NN)
# (CLAUSE work/NN)
# (CLAUSE nature/NN)
# (CLAUSE portfolio/NN review/NN)
# (CLAUSE position/NN)
# (CLAUSE full/JJ consideration/NN)
# (CLAUSE link/NN)
# (CLAUSE portfolio/NN)
# (CLAUSE résumé/NN)
# (CLAUSE portfolio/NN link/NN)
# (CLAUSE résumé/NN)
# (CLAUSE application/NN packet/NN)
# (CLAUSE position/NN)
# (CLAUSE year/NN experience/NN)
# (CLAUSE practice/NN)
# (CLAUSE professional/JJ internship/NN)
# (CLAUSE design/NN)
# (CLAUSE sign/JJ construction/NN)
# (CLAUSE architecture/NN)
# (CLAUSE interior/JJ design/NN)
# (CLAUSE landscape/NN design/NN)
# (CLAUSE modelling/NN experience/NN)
# (CLAUSE experience/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE role…/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE various/JJ software/NN)
# (CLAUSE Experience/NN)
# (CLAUSE film/NN)
# (CLAUSE video/NN editing/NN)
# (CLAUSE digital/JJ compositing/NN)
# (CLAUSE color/NN correction/NN)
# (CLAUSE compression/NN)
# (CLAUSE experience/NN)
# (CLAUSE various/JJ post/NN production/NN)
# (CLAUSE film/NN)
# (CLAUSE video/NN)
# (CLAUSE post-production/NN process/NN)
# (CLAUSE Ability/NN)
# (CLAUSE script/NN)
# (CLAUSE write/JJ software/NN)
# (CLAUSE python/NN)
# (CLAUSE Experience/NN)
# (CLAUSE projection/NN)
# (CLAUSE role…/NN Experience/NN)
# (CLAUSE digital/JJ illustration/NN)
# (CLAUSE software/NN)
# (CLAUSE specific/JJ application/NN)
# (CLAUSE construction/NN documentation/NN)
# (CLAUSE ability/NN)
# (CLAUSE detail/NN)
# (CLAUSE contract/NN documentation/NN)
# (CLAUSE multi-disciplinary/JJ team/NN environment/NN)
# (CLAUSE verbal/JJ communication/NN)
# (CLAUSE Experience/NN)
# (CLAUSE design/NN practice/NN)
# (CLAUSE
#   prior/JJ
#   professional/JJ
#   internship/NN
#   experience/NN
#   Familiarity/NN)
# (CLAUSE design/NN)
# (CLAUSE sign/JJ construction/NN)
# (CLAUSE architecture/NN)
# (CLAUSE interior/JJ design/NN)
# (CLAUSE landscape/NN design/NN)
# (CLAUSE role…/NN)
# (CLAUSE team/NN environment/NN)
# (CLAUSE direction/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE decoration/NN)
# (CLAUSE theatre/NN)
# (CLAUSE film/NN)
# (CLAUSE television/NN)
# (CLAUSE Ability/NN)
# (CLAUSE hand/NN)
# (CLAUSE third/JJ shift/NN)
# (CLAUSE park/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE experience/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE construction/NN)
# (CLAUSE hardware/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE internship/NN)
# (CLAUSE experience/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE concrete/NN)
# (CLAUSE other/JJ hardscape/NN)
# (CLAUSE color/NN design/NN)
# (CLAUSE installation/NN)
# (CLAUSE experience/NN)
# (CLAUSE related/JJ field/NN)
# (CLAUSE professional/JJ ability/NN)
# (CLAUSE design/NN)
# (CLAUSE project/NN execution/NN)
# (CLAUSE Ability/NN)
# (CLAUSE multi-disciplinary/JJ team/NN environment/NN)
# (CLAUSE project/NN execution/NN)
# (CLAUSE landscape/NN architecture/NN)
# (CLAUSE area/NN development/NN)
# (CLAUSE tool/NN)
# (CLAUSE mold/JJ fabrication/NN)
# (CLAUSE responsibility/NN)
# (CLAUSE team/NN)
# (CLAUSE project/NN tracking/NN)
# (CLAUSE estimate/JJ support/NN)
# (CLAUSE management/NN)
# (CLAUSE multi/NN project/NN coordination/NN)
# (CLAUSE role…/NN)
# (CLAUSE paint/NN)
# (CLAUSE commercial/JJ color/NN)
# (CLAUSE scenery/NN)
# (CLAUSE variety/NN)
# (CLAUSE trade/NN)
# (CLAUSE spray/JJ equipment/NN)
# (CLAUSE verbal/JJ direction/NN)
# (CLAUSE implement/NN)
# (CLAUSE variety/NN)
# (CLAUSE team/NN)
# (CLAUSE Familiarity/NN)
# (CLAUSE 3-D/JJ digital/JJ design/NN)
# (CLAUSE technique/NN)
# (CLAUSE internship/NN)
# (CLAUSE related/JJ experience/NN)
# (CLAUSE experience/NN)
# (CLAUSE role…/NN)
# (CLAUSE proficiency/NN)
# (CLAUSE video/NN)
# (CLAUSE presentation/NN)
# (CLAUSE necessary/JJ Understanding/NN)
# (CLAUSE creative/JJ development/NN process/NN)
# (CLAUSE workflow/NN)
# (CLAUSE collaboration/NN)
# (CLAUSE project/NN team/NN)
# (CLAUSE integrated/JJ design/NN)
# (CLAUSE production/NN experience/NN)
# (CLAUSE cost/NN control/NN)
# (CLAUSE engineering/NN experience/NN)
# (CLAUSE experience/NN)
# (CLAUSE similar/JJ facility/NN)
# (CLAUSE construction/NN)
# (CLAUSE Ability/NN)
# (CLAUSE guidance/NN)
# (CLAUSE project/NN team/NN)
# (CLAUSE decision-making/NN)
# (CLAUSE relationship/NN building/NN ability/NN)
# (CLAUSE Projection/NN)
# (CLAUSE i.e/NN)
# (CLAUSE blending/NN)
# (CLAUSE correction/NN)
# (CLAUSE projection/NN)
# (CLAUSE video/NN)
# (CLAUSE selection/NN)
# (CLAUSE operable/JJ projection/NN system/NN)
# (CLAUSE projection/NN)
# (CLAUSE rear/JJ projection/NN screen/NN technology/NN)
# (CLAUSE screen/NN technology/NN)
# (CLAUSE color/NN)
# (CLAUSE spectral/JJ science/NN)
# (CLAUSE experience/NN)
# (CLAUSE legacy/NN)
# (CLAUSE theme/NN park/NN projection/NN)
# (CLAUSE aesthetic/JJ show/NN)
# (CLAUSE communication/NN automation/NN software/NN)
# (CLAUSE experience/NN)
# (CLAUSE experience/NN)
# (CLAUSE integration/NN experience/NN)
# (CLAUSE character/NN animation/NN)
# (CLAUSE experience/NN)
# (CLAUSE production/NN)
# (CLAUSE technical/JJ support/NN)
# (CLAUSE computer/NN)
# (CLAUSE graphic/JJ animation/NN)
# (CLAUSE software/NN knowledge/NN familiarity/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE status/NN)
# (CLAUSE dynamic/JJ work/NN environment/NN)
# (CLAUSE multiple/JJ project/NN)
# (CLAUSE limited/JJ supervision/NN)
# (CLAUSE team/NN)
# (CLAUSE high/JJ tolerance/NN)
# (CLAUSE change/NN)
# (CLAUSE changing/NN)
# (CLAUSE creative/JJ problem/NN solver/NN)
# (CLAUSE comfort/NN)
# (CLAUSE valid/JJ passport/NN)
# (CLAUSE basic/JJ knowledge/NN)
# (CLAUSE control/NN)
# (CLAUSE Experience/NN)
# (CLAUSE motion-capture/NN)
# (CLAUSE administrative/JJ experience/NN)
# (CLAUSE corporate/JJ environment/NN)
# (CLAUSE verbal/JJ communication/NN)
# (CLAUSE wide/JJ range/NN)
# (CLAUSE asynchronous/JJ communication/NN)
# (CLAUSE hybrid/JJ workstyle/NN)
# (CLAUSE High/JJ interest/NN)
# (CLAUSE technology/NN)
# (CLAUSE software/NN product/NN development/NN)
# (CLAUSE culture/NN add/NN)
# (CLAUSE Experience/NN)
# (CLAUSE plus/NN)
# (CLAUSE large/JJ public/JJ corporation/NN)
# (CLAUSE video/NN)
# (CLAUSE equipment/NN)
# (CLAUSE design/NN)
# (CLAUSE implementation/NN)
# (CLAUSE gain/NN scheduling/NN)
# (CLAUSE motor/NN application/NN servo/NN)
# (CLAUSE stepper/NN)
# (CLAUSE vector/NN drive/NN)
# (CLAUSE application/NN)
# (CLAUSE position/NN feedback/NN incremental/NN)
# (CLAUSE absolute/NN)
# (CLAUSE software/NN)
# (CLAUSE computer/NN)
# (CLAUSE power/NN)
# (CLAUSE theory/NN)
# (CLAUSE reading/NN)
# (CLAUSE manner/NN)
# (CLAUSE professional/JJ experience/NN)
# (CLAUSE fifteen/NN)
# (CLAUSE responsibility/NN)
# (CLAUSE motor/NN)
# (CLAUSE drive/JJ specification/NN)
# (CLAUSE motor/NN control/NN design/NN)
# (CLAUSE architecture/NN)
# (CLAUSE industrial/JJ automation/NN)
# (CLAUSE robotic/JJ control/NN)
# (CLAUSE Strong/JJ hardware/NN knowledge/NN)
# (CLAUSE hands-on/JJ field/NN installation/NN experience/NN)
# (CLAUSE supervision/NN)
# (CLAUSE work/NN)
# (CLAUSE team/NN member/NN)
# (CLAUSE high/JJ tolerance/NN)
# (CLAUSE change/NN)
# (CLAUSE changing/NN)
# (CLAUSE ability/NN)
# (CLAUSE relocation/NN)
# (CLAUSE experience/NN)
# (CLAUSE theatrical/JJ design/NN)
# (CLAUSE show/NN development/NN)
# (CLAUSE operation/NN)
# (CLAUSE Experience/NN)
# (CLAUSE creative/JJ process/NN)
# (CLAUSE development/NN)
# (CLAUSE cohesive/JJ design/NN)
# (CLAUSE ability/NN)
# (CLAUSE technology/NN)
# (CLAUSE industry/NN)
# (CLAUSE concert/NN)
# (CLAUSE environment/NN)
# (CLAUSE show/NN)
# (CLAUSE facility/NN)
# (CLAUSE theory/NN)
# (CLAUSE practice/NN)
# (CLAUSE creative/JJ process/NN)
# (CLAUSE experience/NN)
# (CLAUSE practice/NN)
# (CLAUSE show/NN design/NN)
# (CLAUSE system/NN)
# (CLAUSE design/NN)
# (CLAUSE ability/NN)
# (CLAUSE project/NN)
# (CLAUSE scope/NN)
# (CLAUSE schedule/NN)
# (CLAUSE budget/NN)
# (CLAUSE inclination/NN)
# (CLAUSE ability/NN)
# (CLAUSE great/JJ fluency/NN)
# (CLAUSE leadership/NN)
# (CLAUSE work/NN)
# (CLAUSE instruct/NN)
# (CLAUSE problem-solve/NN)
# (CLAUSE installation/NN)
# (CLAUSE focus/NN)
# (CLAUSE delivery/NN)
# (CLAUSE project/NN)
# (CLAUSE computer/NN)
# (CLAUSE industry/NN)
# (CLAUSE specific/JJ software/NN)
# (CLAUSE work/NN schedule/NN)
# (CLAUSE travel/NN)
# (CLAUSE Experience/NN)
# (CLAUSE facility/NN design/NN)
# (CLAUSE engineering/NN)
# (CLAUSE construction/NN)
# (CLAUSE experience/NN)
# (CLAUSE live/JJ show/NN development/NN)
# (CLAUSE heritage/NN)
# (CLAUSE culture/NN)
# (CLAUSE time/NN)
# (CLAUSE multi-lingual/JJ proficiency/NN)
# (CLAUSE role…/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE classroom/NN experience/NN)
# (CLAUSE practice/NN)
# (CLAUSE interior/JJ design/NN)
# (CLAUSE thoughtful/JJ design/NN)
# (CLAUSE professional/JJ judgment/NN)
# (CLAUSE problem/NN solving/NN)
# (CLAUSE proficiency/NN)
# (CLAUSE digital/JJ illustration/NN)
# (CLAUSE License/NN)
# (CLAUSE role/NN)
# (CLAUSE ability/NN)
# (CLAUSE multiple/JJ work/NN)
# (CLAUSE work/NN)
# (CLAUSE work/NN)
# (CLAUSE little/JJ direction/NN)
# (CLAUSE interpersonal/JJ communication/NN)
# (CLAUSE professional/JJ interaction/NN)
# (CLAUSE command/NN)
# (CLAUSE grammar/NN)
# (CLAUSE ability/NN)
# (CLAUSE correspondence/NN)
# (CLAUSE author/NN)
# (CLAUSE team/NN environment/NN)
# (CLAUSE time/NN)
# (CLAUSE initiative/NN)
# (CLAUSE sound/JJ judgment/NN)
# (CLAUSE ability/NN)
# (CLAUSE sensitive/JJ information/NN)
# (CLAUSE Enthusiastic/JJ attitude/NN)
# (CLAUSE strong/JJ work/NN ethic/NN)
# (CLAUSE computer/NN technology/NN)
# (CLAUSE internet-based/JJ research/NN)
# (CLAUSE video/NN)
# (CLAUSE Administrative/JJ experience/NN)
# (CLAUSE corporate/JJ environment/NN)
# (CLAUSE proven/JJ success/NN interacting/NN)
# (CLAUSE management/NN)
# (CLAUSE fast-paced/JJ dynamic/JJ environment/NN)
# (CLAUSE experience/NN)
# (CLAUSE area/NN)
# (CLAUSE design/NN practice/NN)
# (CLAUSE thoughtful/JJ design/NN)
# (CLAUSE design/NN)
# (CLAUSE ability/NN)
# (CLAUSE digital/JJ illustration/NN)
# (CLAUSE design/NN)
# (CLAUSE sign/NN construction/NN)
# (CLAUSE sign/NN design/NN program/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE design/NN)
# (CLAUSE architecture/NN)
# (CLAUSE interior/JJ design/NN)
# (CLAUSE area/NN development/NN)
# (CLAUSE Ability/NN)
# (CLAUSE guidance/NN)
# (CLAUSE project/NN team/NN)
# (CLAUSE decision-making/NN)
# (CLAUSE relationship/NN building/NN ability/NN)
# (CLAUSE estimating/NN)
# (CLAUSE cost/NN control/NN)
# (CLAUSE engineering/NN experience/NN)
# (CLAUSE experience/NN)
# (CLAUSE similar/JJ facility/NN)
# (CLAUSE construction/NN)
# (CLAUSE experience/NN)
# (CLAUSE professional/JJ talent/NN)
# (CLAUSE communication/NN)
# (CLAUSE telephone/NN etiquette/NN)
# (CLAUSE Strong/JJ time/NN management/NN)
# (CLAUSE attention/NN)
# (CLAUSE negotiation/NN)
# (CLAUSE entertainment/NN experience/NN)
# (CLAUSE equivalent/JJ Experience/NN)
# (CLAUSE understanding/NN)
# (CLAUSE knowledge/NN background/NN)
# (CLAUSE music/NN)
# (CLAUSE role…/NN)
# (CLAUSE time/NN)
# (CLAUSE foam/NN core/NN assembly/NN)
# (CLAUSE soldering/NN)
# (CLAUSE woodshop/NN)
# (CLAUSE printing/NN)
# (CLAUSE laser/NN)
# (CLAUSE experience/NN)
# (CLAUSE software/NN)
# (CLAUSE year/NN)
# (CLAUSE experience/NN)
# (CLAUSE role…/NN)
# (CLAUSE proficiency/NN)
# (CLAUSE video/NN)
# (CLAUSE presentation/NN)
# (CLAUSE necessary/JJ Understanding/NN)
# (CLAUSE creative/JJ development/NN process/NN)
# (CLAUSE workflow/NN)
# (CLAUSE collaboration/NN)
# (CLAUSE project/NN team/NN)
# (CLAUSE integrated/JJ design/NN)
# (CLAUSE production/NN experience/NN)
# (CLAUSE year/NN)
# (CLAUSE experience/NN)
# (CLAUSE engineering/NN experience/NN)
# (CLAUSE simulation/NN work/NN)
# (CLAUSE vibration/NN)
# (CLAUSE dynamic/JJ analysis/NN)
# (CLAUSE engineering/NN simulation/NN software/NN)
# (CLAUSE understanding/NN)
# (CLAUSE s/JJ animation/NN pipeline/NN)
# (CLAUSE building/NN)
# (CLAUSE good/JJ communication/NN)
# (CLAUSE vendor/NN relationship/NN)
# (CLAUSE surface/NN modeling/NN)
# (CLAUSE manufacturing/NN)
# (CLAUSE machining/NN)
# (CLAUSE printing/NN)
# (CLAUSE pouring/NN)
# (CLAUSE welding/NN)
# (CLAUSE knowledge/NN)
# (CLAUSE management/NN)
# (CLAUSE skills-/JJ resource/NN loading/NN)
# (CLAUSE scheduling/NN)
# (CLAUSE communication/NN)
# (CLAUSE matrix/NN organization/NN)
# (CLAUSE Strong/JJ familiarity/NN)
# (CLAUSE familiarity/NN)
# (CLAUSE familiarity/NN)
# (CLAUSE animation/NN)
# (CLAUSE Previous/JJ work/NN experience/NN)
# (CLAUSE member/NN)
# (CLAUSE familiarity/NN)
# (CLAUSE motion/NN capture/NN)
# (CLAUSE playback/NN)
# (CLAUSE experience/NN)
# (CLAUSE post-production/NN audio/NN)
# (CLAUSE sound/JJ production/NN)
# (CLAUSE post-production/NN equipment/NN)
# (CLAUSE Understanding/NN)
# (CLAUSE network/NN audio/NN)
# (CLAUSE Ability/NN)
# (CLAUSE minimum/JJ instruction/NN Experience/NN)
# (CLAUSE different/JJ frame/NN)
# (CLAUSE video/NN)
# (CLAUSE Work/NN)
# (CLAUSE patching/NN)
# (CLAUSE digital/JJ routing/NN)
# (CLAUSE equipment/NN operation/NN)
# (CLAUSE signal/JJ flow/NN)
# (CLAUSE equipment/NN)
# (CLAUSE network/NN)
# (CLAUSE Work/NN)
# (CLAUSE new/JJ technology/NN)
# (CLAUSE minimum/NN)
# (CLAUSE instruction/NN)
# (CLAUSE special/JJ venue/NN mixing/NN)
# (CLAUSE location/NN)
# (CLAUSE full-service/JJ production/NN)
# (CLAUSE mix/NN)
# (CLAUSE final/JJ venue/NN)
# (CLAUSE Strong/JJ collaborator/NN)
# (CLAUSE team/NN player/NN)
# (CLAUSE Experience/NN)
# (CLAUSE audio/JJ delivery/NN)
# (CLAUSE intelligibility/NN)
# (CLAUSE workload/NN)
# (CLAUSE role…/NN)
# (CLAUSE collaborative/JJ attitude/NN)
# (CLAUSE excellent/JJ team/NN player/NN)
# (CLAUSE highly-organized/JJ multi-tasker/NN)
# (CLAUSE ability/NN)
# (CLAUSE deadline/JJ pressure/NN)
# (CLAUSE problem/NN solver/NN)
# (CLAUSE eye/NN)
# (CLAUSE information/NN design/NN)
# (CLAUSE management/NN experience/NN)
# (CLAUSE understanding/NN)
# (CLAUSE brand/NN)
# (CLAUSE organization/NN)
# (CLAUSE ability/NN)
# (CLAUSE business/NN)
# (CLAUSE teamwork/NN)
# (CLAUSE proficient/NN)
# (CLAUSE desk/NN research/NN)
# (CLAUSE experience/NN)
# (CLAUSE software/NN)
# (CLAUSE hardware/NN)
# (CLAUSE artificial/JJ intelligence/NN)
# (CLAUSE game/NN engine/NN)
# (CLAUSE project/NN management/NN experience/NN)
# (CLAUSE software/NN development/NN)
# (CLAUSE proven/JJ ability/NN)
# (CLAUSE appropriate/JJ workflow/JJ management/NN methodology/NN)
# (CLAUSE project/NN)
# (CLAUSE kanban/NN)
# (CLAUSE project/NN management/NN)
# (CLAUSE flexibility/NN)
# (CLAUSE adaptability/NN)
# (CLAUSE team/NN)
# (CLAUSE prototyping/NN)
# (CLAUSE playtesting/NN)
# (CLAUSE project/NN)
# (CLAUSE high/JJ level/NN scope/NN vision/NN)
# (CLAUSE ability/NN)
# (CLAUSE project/NN vision/NN)
# (CLAUSE organization/NN)
# (CLAUSE building/NN)
# (CLAUSE environment/NN)
# (CLAUSE passion/NN)
# (CLAUSE technology/NN)
# (CLAUSE desire/NN)
# (CLAUSE strong/JJ work/NN ethic/NN)
# (CLAUSE entrepreneurial/JJ experience/NN)
# (CLAUSE early/JJ development/NN)
# (CLAUSE prototype/NN)
# (CLAUSE science/NN)
# (CLAUSE computer/NN engineering/NN)
# (CLAUSE engineering/NN experience/NN)
# (CLAUSE certification/NN)
# (CLAUSE experience/NN)
# (CLAUSE environment/NN)
# (CLAUSE similar/JJ role/NN)
# (CLAUSE Previous/JJ experience/NN)
# (CLAUSE general/JJ construction/NN)
# (CLAUSE space/NN planning/NN)
# (CLAUSE office/NN)
# (CLAUSE electrical/JJ engineering/NN)
# (CLAUSE Previous/JJ experience/NN)
# (CLAUSE furniture/NN)
# (CLAUSE minimal/JJ travel/NN)
# (CLAUSE vendor/NN)
# (CLAUSE Proficiency/NN)
# []
