# %%
import re
import json
import os
import requests
import time
import numpy as np
import pandas as pd
from datetime import date

from bs4 import BeautifulSoup

# %%
def save(df, cache_path):
    if not os.path.exists(cache_path):
        df.to_csv(cache_path, index=False)
        return df

    df_gospel = pd.read_csv(cache_path)
    df_gospel['cat_id'] = df_gospel['cat_id'].astype(int)
    df_gospel['job_id'] = df_gospel['job_id'].astype(int)

    df_gospel_slim = df_gospel[['cat_id', 'job_id']]
    df_scrapped_new = df \
        .merge(df_gospel_slim, indicator='i', how='outer')

    closed_jobs = df_scrapped_new.query('i == "right_only"')[['cat_id', 'job_id']]
    df_scrapped_new = df_scrapped_new.query('i == "left_only"').drop(['i'], axis=1)

    if not df_scrapped_new.empty:
        df_new = pd.concat([df_gospel, df_scrapped_new], axis=0)
    else:
        df_new = df_gospel.copy()

    for _, row in closed_jobs.iterrows():
        cat_id = row['cat_id']
        job_id = row['job_id']
        q = np.logical_and(df_new['cat_id'] == cat_id, df_new['job_id'] == job_id)
        q = np.logical_and(q, df_new['close'] == '-')
        df_new.loc[q, 'close'] = date.today()

    df_new.to_csv(cache_path, index=False)
    return df_new

# %%
def parse(cache_path):
    p = 1
    total = 20

    jobs = []
    while p <= total:
        url = f'https://jobs.disneycareers.com/search-jobs?k=imagineering&p={p}'
        response = requests.get(url)

        if response.status_code != 200:
            print(f'** ran into an issue {response.status_code}')
            break

        bs = BeautifulSoup(
            response.content,
            features='html.parser'
        )

        total = int(
            re.sub('of\s+', '', bs.select('.pagination-total-pages')[0].text)
        )

        rows = bs.select('#search-results-list tr')
        if len(rows) == 0:
            print('no rows to parse, stopping')
            break

        for row in bs.select('#search-results-list tr'):
            cols = row.select('td')
            if len(cols) < 3:
                continue

            link = cols[0].select('a')[0].attrs['href']
            cat_id = re.search(r'(?<=\/)(\d+)(?=\/\d+$)', link)
            job_id = re.search(r'(?<=\/)(\d+)$', link)

            jobs.append({
                'cat_id': cat_id.group(0),
                'job_id': job_id.group(0),
                'title': re.sub('\s+', ' ', cols[0].text).strip(),
                'date': re.sub('\s+', ' ', cols[1].text).strip(),
                'brand': re.sub('\s+', ' ', cols[2].text).strip(),
                'location': re.sub('\s+', ' ', cols[3].text).strip(),
                'url': f'https://jobs.disneycareers.com{link}',
                'close': '-'
            })

        p += 1
        time.sleep(5)
    
    df = pd.DataFrame(jobs)
    df['cat_id'] = df['cat_id'].astype(int)
    df['job_id'] = df['job_id'].astype(int)
    df['date'] = pd.to_datetime(df.date)

    save(df, cache_path)

parse('../../data/disney/jobs.csv')

# %%
df = pd.read_csv('../../data/disney/jobs.csv').sort_values(['date'], ascending=False)
df.head(n=10)
# Out:
#      cat_id       job_id                                              title  \
# 96      391  27851185408   Staff Mechanical Engineer-Utility and Sustaining
# 19      391  25947875248                                        Show Writer
# 95      391  27851186288  Senior Mechanical Engineer-Utility and Sustaining
# 94      391  27855101056  Senior Manager Research & Development F&B M/F ...
# 135     391  27780781936  Stage Technician, Entertainment (Repair and Ma...
# 49      391   7255959040  Project Interpreter/Translator (English/Japanese)
# 154     391  26439104800  Stage Technician (Lighting/Audio/Video/Rigging...
# 152     391  26469543424        Food Prep - Part Time - $1,000 Hiring Bonus
# 78      391  26288058352                    Senior Manager-Packaging Design
# 171     391  27716762704  Disney Central Orlando Job Fair - $1,500 New H...
#
#            date                            brand  \
# 96   2022-04-24  Parks, Experiences and Products
# 19   2022-04-24  Parks, Experiences and Products
# 95   2022-04-24  Parks, Experiences and Products
# 94   2022-04-24                 Disneyland Paris
# 135  2022-04-23           Shanghai Disney Resort
# 49   2022-04-23  Parks, Experiences and Products
# 154  2022-04-23           Shanghai Disney Resort
# 152  2022-04-22                Disneyland Resort
# 78   2022-04-22  Parks, Experiences and Products
# 171  2022-04-22         Walt Disney World Resort
#
#                                location  \
# 96   Anaheim, California, United States
# 19                         Chiba, Japan
# 95   Anaheim, California, United States
# 94              Marne-la-Vallée, France
# 135            Shanghai, Mainland China
# 49                         Chiba, Japan
# 154            Shanghai, Mainland China
# 152  Anaheim, California, United States
# 78    Kissimmee, Florida, United States
# 171     Orlando, Florida, United States
#
#                                                    url close
# 96   https://jobs.disneycareers.com/job/anaheim/sta...     -
# 19   https://jobs.disneycareers.com/job/chiba/show-...     -
# 95   https://jobs.disneycareers.com/job/anaheim/sen...     -
# 94   https://jobs.disneycareers.com/job/marne-la-va...     -
# 135  https://jobs.disneycareers.com/job/shanghai/st...     -
# 49   https://jobs.disneycareers.com/job/chiba/proje...     -
# 154  https://jobs.disneycareers.com/job/shanghai/st...     -
# 152  https://jobs.disneycareers.com/job/anaheim/foo...     -
# 78   https://jobs.disneycareers.com/job/kissimmee/s...     -
# 171  https://jobs.disneycareers.com/job/orlando/dis...     -

# %%
pd.to_datetime(df.date)
# Out:
# 0     2022-03-29
# 1     2022-04-07
# 2     2022-03-21
# 3     2022-03-27
# 4     2022-04-03
#          ...
# 171   2022-04-19
# 172   2022-04-08
# 173   2022-04-21
# 174   2022-03-22
# 175   2022-04-14
# Name: date, Length: 176, dtype: datetime64[ns]

# %%
df[df.title.str.lower().str.contains('software')]
# Out:
#      cat_id       job_id                                            title  \
# 6       391  24704474480  Associate R&D Imagineer-Tools Software Engineer
# 22      391  24200527168                   Control Software Dev Principal
# 46      391  21407266064                                Software Dev Lead
# 171     391  27550252720                             Sr Software Engineer
#
#               date                                      brand  \
# 6    Mar. 03, 2022                   Walt Disney Imagineering
# 22   Feb. 23, 2022                   Walt Disney Imagineering
# 46   Feb. 22, 2022                   Walt Disney Imagineering
# 171  Apr. 19, 2022  Disney Media & Entertainment Distribution
#
#                                               location  \
# 6    Orlando, Florida, United States / Lake Buena V...
# 22                 Glendale, California, United States
# 46                 Glendale, California, United States
# 171                Bristol, Connecticut, United States
#
#                                                    url close
# 6    https://jobs.disneycareers.com/job/orlando/ass...     -
# 22   https://jobs.disneycareers.com/job/glendale/co...     -
# 46   https://jobs.disneycareers.com/job/glendale/so...     -
# 171  https://jobs.disneycareers.com/job/bristol/sr-...     -

# %%
df[df.title.str.lower().str.contains('data')]
# Out:
#      cat_id       job_id                                     title  \
# 47      391  17617622720            Sr. (Data) Marketing Scientist
# 54      391  25922527760            Sr Analyst, Data Visualization
# 79      391  26229767216            HR Data & Process Analyst (IA)
# 85      391  25137368128             Data Integration Analyst (PH)
# 86      391  25137360720  Data Integration Analyst-Replatform (PH)
# 92      391  16360548592                 Data Integration Engineer
# 117     391  25561189520                              Data Analyst
# 118     391  25561188240                           Sr Data Analyst
# 120     391  25137365136                  Manager, Data Governance
# 127     391  21392955472                 Manager, Data Integration
# 156     391  26192258656                     Data Analyst, Disney+
#
#               date                                brand  \
# 47   Nov. 04, 2021              The Walt Disney Studios
# 54   Mar. 23, 2022  The Walt Disney Company (Corporate)
# 79   Mar. 28, 2022              The Walt Disney Studios
# 85   Mar. 10, 2022  The Walt Disney Company (Corporate)
# 86   Mar. 10, 2022  The Walt Disney Company (Corporate)
# 92   Dec. 27, 2021  The Walt Disney Company (Corporate)
# 117  Mar. 17, 2022                     Disney Streaming
# 118  Mar. 17, 2022                     Disney Streaming
# 120  Mar. 10, 2022  The Walt Disney Company (Corporate)
# 127  Jan. 06, 2022  The Walt Disney Company (Corporate)
# 156  Mar. 28, 2022                     Disney Streaming
#
#                                               location  \
# 47                  Burbank, California, United States
# 54                           California, United States
# 79   Burbank, California, United States / United St...
# 85   Burbank, California, United States / Orlando, ...
# 86   Burbank, California, United States / Orlando, ...
# 92   Orlando, Florida, United States / Lake Buena V...
# 117            Santa Monica, California, United States
# 118            Santa Monica, California, United States
# 120                                      United States
# 127  Orlando, Florida, United States / Lake Buena V...
# 156                               Melbourne, Australia
#
#                                                    url close
# 47   https://jobs.disneycareers.com/job/burbank/sr-...     -
# 54   https://jobs.disneycareers.com/job/california/...     -
# 79   https://jobs.disneycareers.com/job/burbank/hr-...     -
# 85   https://jobs.disneycareers.com/job/burbank/dat...     -
# 86   https://jobs.disneycareers.com/job/burbank/dat...     -
# 92   https://jobs.disneycareers.com/job/orlando/dat...     -
# 117  https://jobs.disneycareers.com/job/santa-monic...     -
# 118  https://jobs.disneycareers.com/job/santa-monic...     -
# 120  https://jobs.disneycareers.com/job/united-stat...     -
# 127  https://jobs.disneycareers.com/job/orlando/man...     -
# 156  https://jobs.disneycareers.com/job/melbourne/d...     -

# %%
df[df.title.str.lower().str.contains('ml')]
# Out:
#    cat_id       job_id                                              title  \
# 7     391  24429981920  Senior AI/ML Research Scientist, Disney Resear...
#
#             date                     brand  \
# 7  Feb. 27, 2022  Walt Disney Imagineering
#
#                               location  \
# 7  Glendale, California, United States
#
#                                                  url close
# 7  https://jobs.disneycareers.com/job/glendale/se...     -

# %%
gosbel_json = []
if os.path.exists('../../data/disney/job_descriptions.json'):
    with open('../../data/disney/job_descriptions.json', 'r') as reader:
        gosbel_json = json.loads(reader.read())

not_closed = df[df['close'] == '-']
for _, row in not_closed.loc[:1].iterrows():
    url = row['url']
    cat_id = row['cat_id']
    job_id = row['job_id']

    if any(filter(lambda a: a['cat_id'] == cat_id and a['job_id'] == job_id, gosbel_json)):
        print(f'already pulled {cat_id}/{job_id}')
        continue

    response = requests.get(url)
    if response.status_code == 200:
        bs = BeautifulSoup(
            response.content,
            features='html.parser'
        )

        description = bs.select('.ats-description')[0]

        gosbel_json.append({
            'cat_id': cat_id,
            'job_id': job_id,
            'description': re.sub('\s+', ' ', f'<html><body>{description}</body></html>')
        })

        time.sleep(5)

with open('../../data/disney/job_descriptions.json', 'w') as writer:
    writer.write(
        json.dumps(gosbel_json, indent=3)
    )

# %%
from IPython.display import display, HTML

gosbel_json = []
with open('../../data/disney/job_descriptions.json', 'r') as reader:
    gosbel_json = json.loads(reader.read())

display(HTML(gosbel_json[0]['description']))
# Out:
# <html><body><div class="ats-description"> <h4>Job Summary:</h4> <div class="additional-field-value-razor"><br/>“Any sufficiently complex technology is indistinguishable from magic.” - Arthur C Clarke<br/><br/><strong>The Team</strong><br/><br/>In a time where children carry devices with AI in their pockets, robots deliver fast food meals, and other science fictions have become mundane reality, we need new magic: New ways to connect with our guests, to surprise them, make them smile, and open their minds to magic - not just in our parks and resorts, but everywhere in the world.<br/><br/>At Disney Research Imagineering this emerges from the application of bleeding edge science to everything from enabling new guest-facing experiences in the parks to assisting cast members and transforming critical business processes.<br/><br/>At Disney Research, we focus on new ideas and ways of thinking, working to solve the biggest challenges that are otherwise unsolvable without deep understanding of both the complexities of the Disney business, and the opportunities afforded by bleeding edge scientific exploration and application.<br/><br/>Our work is centered on 4 key areas<ul><li>Character Intelligence</li><li>General AI/Data Analytics</li><li>Computational Robotics</li><li>Interactive Immersion</li></ul>and is organized around core platforms that enable rapid integration, evaluation, communication and transfer of research concepts and results to the business.<br/><br/><strong>The Role</strong><br/><br/>We are looking for deep applied scientists who are passionate about their field of expertise and want to use their domain knowledge to create magic for our guests and fellow cast members.<br/><br/>As a member of Disney Research Imagineering you will be part of a team that defines and maintains a vision of the future enabled by a melding of deep science with deep artistry within a company that provides an unparalleled platform to share this vision with the world. You will work with partners across the company and academic/industry research teams across the globe to realize this vision: working with talent and leveraging unique data sets and content from the entire spectrum of Disney properties including Parks, Resorts, Cruise Lines, Marvel, Pixar, Lucasfilm, and Disney Animation Studios.<br/><br/>Areas of interest include, but are not limited to:<ul><li>Embodied Conversational AI including:<ul><li>Speech Processing</li><li>Natural Language Understanding</li><li>Dialogue systems</li><li>Voice Synthesis</li><li>Affective Computing</li><li>Knowledge representation</li><li>Generative Animation</li></ul></li><li>Applications of Data Science and Deep/Machine learning<ul><li>Deep generalists</li><li>Recommender systems</li><li>Robotics, control systems</li><li>Computer vision, including activity and action recognition in videos</li></ul></li><li>Computational Behavioral Science<ul><li>Social psychology</li><li>Cognitive science</li><li>Behavioral econometrics</li><li>Behavior and choice modeling</li></ul></li></ul><div><strong>NOTE: General Posting for Post Doc, Associate Research Scientist, Research Scientist, Sr. Research Scientist</strong><br/> </div></div> <h4>Responsibilities:</h4> <br/>As a researcher at Disney Research Imagineering, you will<ul><li>Conduct advanced research projects in areas of interest to Disney Research and our partnering Business Units</li><li>Closely align and integrate with the Disney business to create value for the company by developing cutting edge technology and impactful demonstrators in the form of hardware and software prototypes and demo systems</li><li>Contribute and deliver to major research projects and platforms of Disney Research</li><li>Keep Disney Research at the forefront of technology research by surveying relevant technologies, attending conferences, reading papers, meeting with technology companies and research labs, and sharing new findings with team members.</li><li>Assist in the hiring and mentoring ...

# %%
def break_into_sections(obj):
    html = obj['description']

    bs = BeautifulSoup(
        html,
        features='html.parser'
    )

    ignore_sections = ['Additional Information:']
    job_description_sections = []
    sections = list(map(lambda a: a.text, bs.select('h4')))
    for start, end in zip(sections, [*sections[1:], '-1']):
        if start in ignore_sections:
            continue

        if end != '-1':
            q = f'(?<=<h4>{start}</h4>)(.+?)(<h4>{end}</h4>)'
        else:
            q = f'(?<=<h4>{start}</h4>)(.+)'
        
        match_html = re.search(q, html).group(1)
        match_html = re.sub('<ul>', '\n\n<ul>', match_html)
        match_html = re.sub('</ul>', '</ul>\n\n', match_html)
        match_html = re.sub('<li>', '<li>* ', match_html)
        match_html = re.sub('</li>', '\n</li>', match_html)

        bs2 = BeautifulSoup(
            match_html,
            features='html.parser'
        )

        text = bs2.get_text()
        text = re.sub(r'(\n\n)(\* )([^\n]+)(\n\n)', r'\1\3\n', text)
        job_description_sections.append({
            'section': re.sub(':\s*$', '', start).strip(),
            'text': text.strip()
        })

    return job_description_sections
# Out:
# [{'section': 'Job Summary',
#   'text': '“Any sufficiently complex technology is indistinguishable from magic.” - Arthur C ClarkeThe TeamIn a time where children carry devices with AI in their pockets, robots deliver fast food meals, and other science fictions have become mundane reality, we need new magic: New ways to connect with our guests, to surprise them, make them smile, and open their minds to magic - not just in our parks and resorts, but everywhere in the world.At Disney Research Imagineering this emerges from the application of bleeding edge science to everything from enabling new guest-facing experiences in the parks to assisting cast members and transforming critical business processes.At Disney Research, we focus on new ideas and ways of thinking, working to solve the biggest challenges that are otherwise unsolvable without deep understanding of both the complexities of the Disney business, and the opportunities afforded by bleeding edge scientific exploration and application.Our work is centered on 4 key areas\n\n* Character Intelligence\n* General AI/Data Analytics\n* Computational Robotics\n* Interactive Immersion\n\n\nand is organized around core platforms that enable rapid integration, evaluation, communication and transfer of research concepts and results to the business.The RoleWe are looking for deep applied scientists who are passionate about their field of expertise and want to use their domain knowledge to create magic for our guests and fellow cast members.As a member of Disney Research Imagineering you will be part of a team that defines and maintains a vision of the future enabled by a melding of deep science with deep artistry within a company that provides an unparalleled platform to share this vision with the world. You will work with partners across the company and academic/industry research teams across the globe to realize this vision: working with talent and leveraging unique data sets and content from the entire spectrum of Disney properties including Parks, Resorts, Cruise Lines, Marvel, Pixar, Lucasfilm, and Disney Animation Studios.Areas of interest include, but are not limited to:\n\nEmbodied Conversational AI including:\n* Speech Processing\n* Natural Language Understanding\n* Dialogue systems\n* Voice Synthesis\n* Affective Computing\n* Knowledge representation\n* Generative Animation\n\nApplications of Data Science and Deep/Machine learning\n* Deep generalists\n* Recommender systems\n* Robotics, control systems\n* Computer vision, including activity and action recognition in videos\n\nComputational Behavioral Science\n* Social psychology\n* Cognitive science\n* Behavioral econometrics\n* Behavior and choice modeling\n\n\nNOTE: General Posting for Post Doc, Associate Research Scientist, Research Scientist, Sr. Research Scientist'},
#  {'section': 'Responsibilities',
#   'text': 'As a researcher at Disney Research Imagineering, you will\n\n* Conduct advanced research projects in areas of interest to Disney Research and our partnering Business Units\n* Closely align and integrate with the Disney business to create value for the company by developing cutting edge technology and impactful demonstrators in the form of hardware and software prototypes and demo systems\n* Contribute and deliver to major research projects and platforms of Disney Research\n* Keep Disney Research at the forefront of technology research by surveying relevant technologies, attending conferences, reading papers, meeting with technology companies and research labs, and sharing new findings with team members.\n* Assist in the hiring and mentoring of Researchers, Lab Associates and Interns\n* Draft and submit strategic papers and patents based on research\n* Establish and maintain effective working relations with collaborators within and external to the company.'},
#  {'section': 'Basic Qualifications',
#   'text': '* You are passionate about your area of expertise, deeply inquisitive and open minded, informed, but not limited, by your domain of expertise.\n* You enjoy intellectual debate.\n* You are comfortable guiding other team members but willing to get your hands dirty and help build research systems when needed\n* You are driven to perform research that is not simply novel, but deeply impactful to the company and society have a deep desire to reduce the research to practice in the form of prototypes and technology demonstrators.\n* You are excited by the platform provided by Disney to connect with children and guests of all ages to have a positive impact on the world.\n* You have a deep sensitivity for ethical use of technology and data.\n* You thrive in a fast-paced collaborative environment.\n* You are self-directed and independent, but open to constructive feedback.\n* You are a team player, able to work in collaborative interdisciplinary groups\n* You are willing to take the time necessary to understand the business and adapt your knowledge to maximize the value of your contributions.\n* You understand that communicating the value of your research to non-technical stakeholders is critical to continued investment.\n* You understand that there are times when deep scientific rigor is necessary to validate a concept, and times when this is counterproductive, and are eager to discern the difference.\n* You value sharing knowledge with the world but understand the need to drive and retain value in a private company.'},
#  {'section': 'Required Education', 'text': 'PhD in relevant research area'}]

# %%
headers = []
for item in gosbel_json:
  headers.extend(list(map(lambda a: a['section'], item['sections'])))

set(headers)
# Out:
# {'Basic Qualifications',
#  'Job Summary',
#  'Preferred Education',
#  'Preferred Qualifications',
#  'Required Education',
#  'Responsibilities'}
